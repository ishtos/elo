# %%
import os
import sys
import gc
import datetime
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import lightgbm as lgb

from glob import glob
from tqdm import tqdm
from collections import defaultdict
from multiprocessing import cpu_count, Pool

from sklearn.decomposition import PCA
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.metrics import mean_squared_error

import warnings
warnings.simplefilter('ignore')

# %%
pd.options.display.max_columns = None

# %%
KEY = 'card_id'

SEED = 6

NTHREAD = cpu_count()

NFOLD = 11

# %%
PATH = os.path.join('..', 'input')
train = pd.read_csv(os.path.join(PATH, 'train.csv'))
test = pd.read_csv(os.path.join(PATH, 'test.csv'))

# %%
train['outliers'] = 0
train.loc[train['target'] < -30, 'outliers'] = 1
train['target_raw'] = 2**train['target']

test['target'] = np.nan
test['target_raw'] = np.nan

df = pd.concat([train, test], axis=0)

del train, test
gc.collect()

df['first_active_month'] = pd.to_datetime(df['first_active_month'])
df['elapsed_time'] = (datetime.date(2018, 5, 1) - df['first_active_month'].dt.date).dt.days

features = ['feature_1', 'feature_2', 'feature_3']
for f in features:
    map_mean = df.groupby(f)['outliers'].mean()
    map_sum = df.groupby(f)['outliers'].sum()
    df[f + '_outliers_mean'] = df[f].map(map_mean)
    df[f + '_outliers_sum'] = df[f].map(map_sum)

train = df[df['target'].notnull()]
test = df[df['target'].isnull()]

del df
gc.collect()
# Out:
# 113

# %%
train.head()
# Out:
#            card_id  feature_1  feature_2  feature_3 first_active_month  \
# 0  C_ID_92a2005557          5          2          1         2017-06-01
# 1  C_ID_3d0044924f          4          1          0         2017-01-01
# 2  C_ID_d639edf6cd          2          2          0         2016-08-01
# 3  C_ID_186d6a6901          4          3          0         2017-09-01
# 4  C_ID_cdbd2c0db2          1          3          0         2017-11-01
#
#    outliers    target  target_raw  elapsed_time  feature_1_outliers_mean  \
# 0       0.0 -0.820283    0.566331         334.0                 0.013145
# 1       0.0  0.392913    1.313042         485.0                 0.010712
# 2       0.0  0.688056    1.611111         638.0                 0.010610
# 3       0.0  0.142495    1.103813         242.0                 0.010712
# 4       0.0 -0.159749    0.895181         181.0                 0.008058
#
#    feature_1_outliers_sum  feature_2_outliers_mean  feature_2_outliers_sum  \
# 0                   534.0                 0.008752                   655.0
# 1                   213.0                 0.011385                  1016.0
# 2                   592.0                 0.008752                   655.0
# 3                   213.0                 0.014166                   536.0
# 4                    97.0                 0.014166                   536.0
#
#    feature_3_outliers_mean  feature_3_outliers_sum
# 0                 0.011428                  1305.0
# 1                 0.010283                   902.0
# 2                 0.010283                   902.0
# 3                 0.010283                   902.0
# 4                 0.010283                   902.0

# %%
historical_transactions = pd.read_csv(os.path.join(PATH, 'historical_transactions.csv'))
new_merchant_transactions = pd.read_csv(os.path.join(PATH, 'new_merchant_transactions.csv'))

# %%
new_merchant_transactions['purchase_amount_new'] = np.round(new_merchant_transactions['purchase_amount'] / 0.00150265118 + 497.06,2)
historical_transactions['purchase_amount_new'] = np.round(historical_transactions['purchase_amount'] / 0.00150265118 + 497.06,2)

# %%
def hist_aggregate():
    hist_df = pd.read_csv(os.path.join(PATH, 'historical_transactions.csv'))

    hist_df['purchase_date'] = pd.to_datetime(hist_df['purchase_date'])
    hist_df['year'] = hist_df['purchase_date'].dt.year
    hist_df['month'] = hist_df['purchase_date'].dt.month
    hist_df['weekofyear'] = hist_df['purchase_date'].dt.weekofyear
    hist_df['day'] = hist_df['purchase_date'].dt.day
    hist_df['weekend'] = (hist_df['purchase_date'].dt.weekday >= 5).astype(int)
    hist_df['hour'] = hist_df['purchase_date'].dt.hour
    
    hist_df['authorized_flag'] = hist_df['authorized_flag'].map({'Y': 1, 'N': 0}).astype(int)
    
    hist_df['category_1'] = hist_df['category_1'].map({'Y': 1, 'N': 0}).astype(int)
    hist_df['category_2'] = hist_df['category_2'].fillna(0).astype(int)
    hist_df['category_3'] = hist_df['category_3'].map({'A': 3, 'B': 2, 'C': 1, np.nan: 0})
    
    hist_df['installments_999'] = hist_df['installments'].apply(lambda x: np.where(x == 999, 1, 0))
    hist_df['installments'] = hist_df['installments'].apply(lambda x: np.where((x == 999) or (x == -1), np.nan, x))
    
    hist_df['merchant_id'] = hist_df['merchant_id'].fillna('ONLINE')
    
    hist_df['city_minus_one'] = hist_df['city_id'].apply(lambda x: np.where(x == -1, 1, 0))
    hist_df['merchant_category_minus_one'] =  hist_df['merchant_category_id'].apply(lambda x: np.where(x == -1, 1, 0))
    hist_df['subsector_minus_one'] = hist_df['subsector_id'].apply(lambda x: np.where(x == -1, 1, 0))

    hist_df['purchase_amount_new'] = np.round(hist_df['purchase_amount'] / 0.00150265118 + 497.06, 2)
    
    pt1 = pd.pivot_table(
        hist_df, 
        index='card_id', columns='month_lag', values=['purchase_amount_new'], 
        aggfunc=['sum']).reset_index()
    pt1.columns = [f'{c[0]}_{c[1]}_{c[2]}'.replace('-', '').strip('_') for c in pt1.columns]
    
    pt2 = pd.pivot_table(
        hist_df, 
        index='card_id', columns='month_lag', values=['merchant_id'], 
        aggfunc=['count']).reset_index()
    pt2.columns = [f'{c[0]}_{c[1]}_{c[2]}'.replace('-', '').strip('_') for c in pt2.columns]
        
    num_aggregations = {
        'authorized_flag': ['sum', 'mean'],
        
        'purchase_amount_new': ['sum'],
        'purchase_date': ['max', 'min'],
        
        'year': ['nunique'],
        'month': ['nunique', 'mean'],
        'weekofyear': ['nunique', 'mean'],
        'day': ['nunique', 'mean'],
        'weekend': ['sum', 'mean'],
        'hour': ['nunique', 'mean'],
        
        'category_1': ['sum', 'mean'],
        'category_2': ['sum', 'mean'],
        'category_3': ['sum', 'mean'],
        
        'city_id': ['nunique'],
        'merchant_category_id': ['nunique'],
        'merchant_id': ['nunique'],
        'state_id': ['nunique'],
        'subsector_id': ['nunique'],
        
        'city_minus_one': ['sum', 'mean'],
        'merchant_category_minus_one': ['sum', 'mean'],
        'subsector_minus_one': ['sum', 'mean'],
        
        'installments_999': ['sum', 'mean'],

        'month_lag': ['max', 'min', 'sum', 'mean', 'std']        
    }
    
    g1 = hist_df.groupby(['card_id']).agg(num_aggregations).reset_index()
    g1.columns = [f'{c[0]}_{c[1]}'.strip('_') for c in g1.columns]
    g1 = g1.add_prefix('hist_')
    g1 = g1.rename(columns={'hist_card_id': 'card_id'})
    
    num_aggregations = {
        'purchase_amount_new': ['sum'],
        'purchase_date': ['max', 'min'],

        'city_id': ['nunique'],
        'merchant_category_id': ['nunique'],
        'merchant_id': ['nunique'],
        'state_id': ['nunique'],
        'subsector_id': ['nunique'],
    }
    g2 = hist_df.groupby(['card_id', 'authorized_flag']).agg(num_aggregations).reset_index()
    g2.columns = [f'{c[0]}_{c[1]}'.strip('_') for c in g2.columns]
    
    g2_Y = g2.query('authorized_flag == 1')
    g2_Y = g2_Y.add_prefix('Y_hist_')
    g2_Y = g2_Y.rename(columns={'Y_hist_card_id': 'card_id'})
    g2_N = g2.query('authorized_flag == 0')
    g2_N = g2_N.add_prefix('N_hist_')
    g2_N = g2_N.rename(columns={'N_hist_card_id': 'card_id'})
    g2 = pd.merge(g2_Y, g2_N, on='card_id', how='left') 
    g2 = g2.drop(['Y_hist_authorized_flag', 'N_hist_authorized_flag'], axis=1)
    
    pt = pd.merge(pt1, pt2, on='card_id', how='left')
    g = pd.merge(g1, g2, on='card_id', how='left')
    feature = pd.merge(pt, g, on='card_id', how='left')

    return feature

# %%
def new_aggregate():
    new_df = pd.read_csv(os.path.join(PATH, 'new_merchant_transactions.csv'))

    new_df['purchase_date'] = pd.to_datetime(new_df['purchase_date'])
    new_df['year'] = new_df['purchase_date'].dt.year
    new_df['month'] = new_df['purchase_date'].dt.month
    new_df['weekofyear'] = new_df['purchase_date'].dt.weekofyear
    new_df['day'] = new_df['purchase_date'].dt.day
    new_df['weekend'] = (new_df['purchase_date'].dt.weekday >= 5).astype(int)
    new_df['hour'] = new_df['purchase_date'].dt.hour
        
    new_df['category_1'] = new_df['category_1'].map({'Y': 1, 'N': 0}).astype(int)
    new_df['category_2'] = new_df['category_2'].fillna(0).astype(int)
    new_df['category_3'] = new_df['category_3'].map({'A': 3, 'B': 2, 'C': 1, np.nan: 0})
    
    new_df['installments_999'] = new_df['installments'].apply(lambda x: np.where(x == 999, 1, 0))
    new_df['installments'] = new_df['installments'].apply(lambda x: np.where((x == 999) or (x == -1), np.nan, x))
    new_df['merchant_id'] = new_df['merchant_id'].fillna('ONLINE')
    
        
    new_df['city_minus_one'] = new_df['city_id'].apply(lambda x: np.where(x == -1, 1, 0))
    new_df['merchant_category_minus_one'] =  new_df['merchant_category_id'].apply(lambda x: np.where(x == -1, 1, 0))
    new_df['subsector_minus_one'] = new_df['subsector_id'].apply(lambda x: np.where(x == -1, 1, 0))
    
    new_df['purchase_amount_new'] = np.round(new_df['purchase_amount'] / 0.00150265118 + 497.06, 2)
    
    pt1 = pd.pivot_table(
        new_df, 
        index='card_id', columns='month_lag', values=['purchase_amount_new'], 
        aggfunc=['sum']).reset_index()
    pt1.columns = [f'{c[0]}_{c[1]}_{c[2]}'.replace('-', '').strip('_') for c in pt1.columns]
    
    pt2 = pd.pivot_table(
        new_df, 
        index='card_id', columns='month_lag', values=['merchant_id'], 
        aggfunc=['count']).reset_index()
    pt2.columns = [f'{c[0]}_{c[1]}_{c[2]}'.replace('-', '').strip('_') for c in pt2.columns]
        
    num_aggregations = { 
        'purchase_amount_new': ['sum'],
        'purchase_date': ['max', 'min'],
        'year': ['nunique'],
        'month': ['nunique', 'mean'],
        'weekofyear': ['nunique', 'mean'],
        'day': ['nunique', 'mean'],
        'weekend': ['sum', 'mean'],
        'hour': ['nunique', 'mean'],
        
        'category_1': ['sum', 'mean'],
        'category_2': ['sum', 'mean'],
        'category_3': ['sum', 'mean'],
        
        'city_id': ['nunique'],
        'merchant_category_id': ['nunique'],
        'merchant_id': ['nunique'],
        'state_id': ['nunique'],
        'subsector_id': ['nunique'],
        
        'installments_999': ['sum', 'mean'],

        'month_lag': ['max', 'min', 'sum', 'mean', 'std']        
    }
    
    g = new_df.groupby(['card_id']).agg(num_aggregations).reset_index()
    g.columns = [f'{c[0]}_{c[1]}'.strip('_') for c in g.columns]
    g = g.add_prefix('new_')
    g = g.rename(columns={'new_card_id': 'card_id'})
    
    feature = pd.merge(pt1, pt2, on='card_id', how='left')
    feature = pd.merge(feature, g, on='card_id', how='left')
    
    return feature

# %%
hist_df = hist_aggregate()

# %%
new_df = new_aggregate()

# %%
hist_df.head()
# Out:
#            card_id  sum_purchase_amount_new_13  sum_purchase_amount_new_12  \
# 0  C_ID_00007093c1                         NaN                     1100.20
# 1  C_ID_0001238066                         NaN                         NaN
# 2  C_ID_0001506ef0                        51.0                      184.48
# 3  C_ID_0001793786                         NaN                         NaN
# 4  C_ID_000183fdda                         NaN                         NaN
#
#    sum_purchase_amount_new_11  sum_purchase_amount_new_10  \
# 0                     1168.90                     1633.25
# 1                         NaN                         NaN
# 2                      286.53                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#    sum_purchase_amount_new_9  sum_purchase_amount_new_8  \
# 0                    2691.13                    2876.63
# 1                        NaN                        NaN
# 2                      30.00                      24.87
# 3                    1269.83                    3745.99
# 4                        NaN                        NaN
#
#    sum_purchase_amount_new_7  sum_purchase_amount_new_6  \
# 0                    1307.79                    4189.00
# 1                        NaN                        NaN
# 2                    1017.00                     849.50
# 3                    7389.91                    7783.04
# 4                        NaN                    2831.40
#
#    sum_purchase_amount_new_5  sum_purchase_amount_new_4  \
# 0                     524.57                    1513.59
# 1                     127.13                     943.03
# 2                     770.50                     910.74
# 3                    3380.25                   14441.70
# 4                    1675.01                    2326.11
#
#    sum_purchase_amount_new_3  sum_purchase_amount_new_2  \
# 0                     940.25                    1985.22
# 1                    1831.55                    4121.19
# 2                    1089.28                    1579.29
# 3                   13971.57                    9683.56
# 4                    2237.65                    4312.91
#
#    sum_purchase_amount_new_1  sum_purchase_amount_new_0  count_merchant_id_13  \
# 0                    1186.59                    1805.18                   NaN
# 1                    3884.94                    2017.62                   NaN
# 2                    1365.30                    1620.25                   2.0
# 3                   14936.02                    6282.35                   NaN
# 4                    8872.47                    3510.10                   NaN
#
#    count_merchant_id_12  count_merchant_id_11  count_merchant_id_10  \
# 0                   4.0                  10.0                  12.0
# 1                   NaN                   NaN                   NaN
# 2                   5.0                   8.0                   NaN
# 3                   NaN                   NaN                   NaN
# 4                   NaN                   NaN                   NaN
#
#    count_merchant_id_9  count_merchant_id_8  count_merchant_id_7  \
# 0                 10.0                 19.0                 15.0
# 1                  NaN                  NaN                  NaN
# 2                  1.0                  3.0                  2.0
# 3                  2.0                  6.0                 16.0
# 4                  NaN                  NaN                  NaN
#
#    count_merchant_id_6  count_merchant_id_5  count_merchant_id_4  \
# 0                 17.0                  5.0                 17.0
# 1                  NaN                  2.0                 11.0
# 2                  2.0                  2.0                  3.0
# 3                 30.0                  4.0                 37.0
# 4                  6.0                 22.0                 25.0
#
#    count_merchant_id_3  count_merchant_id_2  count_merchant_id_1  \
# 0                  6.0                 12.0                 10.0
# 1                 23.0                 37.0                 26.0
# 2                  7.0                 18.0                  7.0
# 3                 29.0                 34.0                 38.0
# 4                  9.0                 26.0                 28.0
#
#    count_merchant_id_0  hist_authorized_flag_sum  hist_authorized_flag_mean  \
# 0                 12.0                       114                   0.765101
# 1                 24.0                       120                   0.975610
# 2                  6.0                        62                   0.939394
# 3                 20.0                       189                   0.875000
# 4                 28.0                       137                   0.951389
#
#    hist_purchase_amount_new_sum hist_purchase_date_max hist_purchase_date_min  \
# 0                      22922.30    2018-02-27 05:14:57    2017-02-14 14:00:43
# 1                      12925.46    2018-02-27 16:18:59    2017-09-28 22:25:14
# 2                       9778.74    2018-02-17 12:33:56    2017-01-14 16:16:01
# 3                      82884.22    2017-10-31 20:20:18    2017-01-21 10:15:21
# 4                      25765.65    2018-02-25 20:57:08    2017-08-07 09:49:14
#
#    hist_year_nunique  hist_month_nunique  hist_month_mean  \
# 0                  2                  12         6.375839
# 1                  2                   6         7.308943
# 2                  2                  11         6.803030
# 3                  1                  10         6.671296
# 4                  2                   7         6.881944
#
#    hist_weekofyear_nunique  hist_weekofyear_mean  hist_day_nunique  \
# 0                       39             25.550336                28
# 1                       23             29.967480                30
# 2                       24             27.090909                25
# 3                       33             27.134259                31
# 4                       27             27.881944                30
#
#    hist_day_mean  hist_weekend_sum  hist_weekend_mean  hist_hour_nunique  \
# 0      13.248322                25           0.167785                 18
# 1      16.138211                52           0.422764                 20
# 2      12.000000                32           0.484848                 15
# 3      16.115741                37           0.171296                 21
# 4      14.034722                33           0.229167                 19
#
#    hist_hour_mean  hist_category_1_sum  hist_category_1_mean  \
# 0       14.416107                   28              0.187919
# 1       14.739837                    2              0.016260
# 2       12.606061                    0              0.000000
# 3       15.606481                    2              0.009259
# 4       16.465278                    4              0.027778
#
#    hist_category_2_sum  hist_category_2_mean  hist_category_3_sum  \
# 0                  365              2.449664                  274
# 1                  195              1.585366                  208
# 2                  194              2.939394                  197
# 3                  208              0.962963                  643
# 4                  407              2.826389                  243
#
#    hist_category_3_mean  hist_city_id_nunique  \
# 0              1.838926                     4
# 1              1.691057                    18
# 2              2.984848                     3
# 3              2.976852                    10
# 4              1.687500                     9
#
#    hist_merchant_category_id_nunique  hist_merchant_id_nunique  \
# 0                                 18                        29
# 1                                 29                        65
# 2                                 19                        28
# 3                                 48                       119
# 4                                 36                        73
#
#    hist_state_id_nunique  hist_subsector_id_nunique  hist_city_minus_one_sum  \
# 0                      3                         13                       28
# 1                      6                         17                        8
# 2                      2                         12                        0
# 3                      4                         24                        2
# 4                      7                         21                        4
#
#    hist_city_minus_one_mean  hist_merchant_category_minus_one_sum  \
# 0                  0.187919                                     0
# 1                  0.065041                                     0
# 2                  0.000000                                     0
# 3                  0.009259                                     0
# 4                  0.027778                                     0
#
#    hist_merchant_category_minus_one_mean  hist_subsector_minus_one_sum  \
# 0                                    0.0                             0
# 1                                    0.0                             0
# 2                                    0.0                             0
# 3                                    0.0                             0
# 4                                    0.0                             0
#
#    hist_subsector_minus_one_mean  hist_installments_999_sum  \
# 0                            0.0                          0
# 1                            0.0                          0
# 2                            0.0                          0
# 3                            0.0                          0
# 4                            0.0                          0
#
#    hist_installments_999_mean  hist_month_lag_max  hist_month_lag_min  \
# 0                         0.0                   0                 -12
# 1                         0.0                   0                  -5
# 2                         0.0                   0                 -13
# 3                         0.0                   0                  -9
# 4                         0.0                   0                  -6
#
#    hist_month_lag_sum  hist_month_lag_mean  hist_month_lag_std  \
# 0                -872            -5.852349            3.453114
# 1                -223            -1.813008            1.288980
# 2                -319            -4.833333            4.237500
# 3                -719            -3.328704            2.306373
# 4                -353            -2.451389            1.895264
#
#    Y_hist_purchase_amount_new_sum Y_hist_purchase_date_max  \
# 0                        15109.57      2018-02-27 05:14:57
# 1                        12625.46      2018-02-27 16:18:59
# 2                         9724.27      2018-02-17 12:33:56
# 3                        77333.25      2017-10-31 20:20:18
# 4                        22912.71      2018-02-25 20:57:08
#
#   Y_hist_purchase_date_min  Y_hist_city_id_nunique  \
# 0      2017-02-14 14:00:43                       4
# 1      2017-09-28 22:25:14                      18
# 2      2017-01-14 16:16:01                       3
# 3      2017-01-21 10:15:21                       9
# 4      2017-09-03 13:00:12                       9
#
#    Y_hist_merchant_category_id_nunique  Y_hist_merchant_id_nunique  \
# 0                                   18                          28
# 1                                   29                          65
# 2                                   19                          28
# 3                                   45                         114
# 4                                   34                          71
#
#    Y_hist_state_id_nunique  Y_hist_subsector_id_nunique  \
# 0                        3                           13
# 1                        6                           17
# 2                        2                           12
# 3                        4                           22
# 4                        7                           20
#
#    N_hist_purchase_amount_new_sum N_hist_purchase_date_max  \
# 0                         7812.73      2018-02-08 16:37:19
# 1                          300.00      2018-02-10 13:22:21
# 2                           54.47      2018-02-17 12:33:27
# 3                         5550.97      2017-09-14 19:07:17
# 4                         2852.94      2017-10-23 23:22:23
#
#   N_hist_purchase_date_min  N_hist_city_id_nunique  \
# 0      2017-03-11 16:28:46                     3.0
# 1      2017-12-30 18:49:51                     2.0
# 2      2017-06-06 17:58:52                     1.0
# 3      2017-03-04 13:56:41                     8.0
# 4      2017-08-07 09:49:14                     1.0
#
#    N_hist_merchant_category_id_nunique  N_hist_merchant_id_nunique  \
# 0                                  8.0                        11.0
# 1                                  1.0                         2.0
# 2                                  4.0                         4.0
# 3                                 14.0                        17.0
# 4                                  4.0                         4.0
#
#    N_hist_state_id_nunique  N_hist_subsector_id_nunique
# 0                      2.0                          7.0
# 1                      2.0                          1.0
# 2                      1.0                          4.0
# 3                      4.0                         11.0
# 4                      1.0                          4.0

# %%
new_df.head()
# Out:
#            card_id  sum_purchase_amount_new_1  sum_purchase_amount_new_2  \
# 0  C_ID_00007093c1                        NaN                     110.00
# 1  C_ID_0001238066                    1957.98                    1083.01
# 2  C_ID_0001506ef0                      30.92                        NaN
# 3  C_ID_0001793786                   11552.90                    3703.15
# 4  C_ID_000183fdda                     575.28                     506.28
#
#    count_merchant_id_1  count_merchant_id_2  new_purchase_amount_new_sum  \
# 0                  NaN                  2.0                       110.00
# 1                 17.0                  9.0                      3040.99
# 2                  2.0                  NaN                        30.92
# 3                 21.0                 10.0                     15256.05
# 4                  8.0                  3.0                      1081.56
#
#   new_purchase_date_max new_purchase_date_min  new_year_nunique  \
# 0   2018-04-09 16:23:59   2018-04-03 11:13:35                 1
# 1   2018-04-30 19:57:30   2018-03-01 16:48:27                 1
# 2   2018-03-22 09:14:30   2018-03-16 22:21:58                 1
# 3   2017-12-31 17:35:56   2017-11-15 15:44:20                 1
# 4   2018-04-30 14:59:53   2018-03-02 12:26:26                 1
#
#    new_month_nunique  new_month_mean  new_weekofyear_nunique  \
# 0                  1        4.000000                       2
# 1                  2        3.346154                       9
# 2                  1        3.000000                       2
# 3                  2       11.322581                       6
# 4                  2        3.272727                       7
#
#    new_weekofyear_mean  new_day_nunique  new_day_mean  new_weekend_sum  \
# 0            14.500000                2      6.000000                0
# 1            12.846154               14     18.230769               12
# 2            11.500000                2     19.000000                0
# 3            48.387097               13     23.612903               14
# 4            11.818182                9     11.727273                2
#
#    new_weekend_mean  new_hour_nunique  new_hour_mean  new_category_1_sum  \
# 0          0.000000                 2      13.500000                   0
# 1          0.461538                16      15.192308                   2
# 2          0.000000                 2      15.500000                   0
# 3          0.451613                10      11.419355                   0
# 4          0.181818                 8      15.454545                   0
#
#    new_category_1_mean  new_category_2_sum  new_category_2_mean  \
# 0             0.000000                   4             2.000000
# 1             0.076923                  35             1.346154
# 2             0.000000                   6             3.000000
# 3             0.000000                  51             1.645161
# 4             0.000000                  33             3.000000
#
#    new_category_3_sum  new_category_3_mean  new_city_id_nunique  \
# 0                   4             2.000000                    2
# 1                  46             1.769231                    8
# 2                   6             3.000000                    1
# 3                  93             3.000000                    7
# 4                  16             1.454545                    2
#
#    new_merchant_category_id_nunique  new_merchant_id_nunique  \
# 0                                 2                        2
# 1                                15                       26
# 2                                 2                        2
# 3                                21                       31
# 4                                 9                       11
#
#    new_state_id_nunique  new_subsector_id_nunique  new_installments_999_sum  \
# 0                     2                         2                         0
# 1                     4                         9                         0
# 2                     1                         2                         0
# 3                     5                        14                         0
# 4                     2                         6                         0
#
#    new_installments_999_mean  new_month_lag_max  new_month_lag_min  \
# 0                        0.0                  2                  2
# 1                        0.0                  2                  1
# 2                        0.0                  1                  1
# 3                        0.0                  2                  1
# 4                        0.0                  2                  1
#
#    new_month_lag_sum  new_month_lag_mean  new_month_lag_std
# 0                  4            2.000000           0.000000
# 1                 35            1.346154           0.485165
# 2                  2            1.000000           0.000000
# 3                 41            1.322581           0.475191
# 4                 14            1.272727           0.467099

# %%
hist_df.shape, new_df.shape
# Out:
# ((325540, 85), (290001, 37))

# %%
for df in (hist_df, new_df):
    train = pd.merge(train, df, on='card_id', how='left')
    test = pd.merge(test, df, on='card_id', how='left')

# %%
df = pd.concat([train, test], axis=0)
df['first_active_month'] = pd.to_datetime(df['first_active_month'])

df['hist_first_buy'] = (df['hist_purchase_date_min'].dt.date - df['first_active_month'].dt.date).dt.days
df['hist_last_buy'] = (df['hist_purchase_date_max'].dt.date - df['first_active_month'].dt.date).dt.days
df['new_first_buy'] = (df['new_purchase_date_min'].dt.date - df['first_active_month'].dt.date).dt.days
df['new_last_buy'] = (df['new_purchase_date_max'].dt.date - df['first_active_month'].dt.date).dt.days

date_features = [
    'hist_purchase_date_max','hist_purchase_date_min',
    'Y_hist_purchase_date_min', 'N_hist_purchase_date_min',
    'Y_hist_purchase_date_max', 'N_hist_purchase_date_max',
    'new_purchase_date_max', 'new_purchase_date_min',
]

for f in date_features:
    df[f] = df[f].astype(np.int64) * 1e-9

df['nans'] = df.isnull().sum(axis=1)

train = df[df['target'].notnull()]
test = df[df['target'].isnull()]

categorical_features = ['feature_1', 'feature_2', 'feature_3']
pca = PCA(n_components=1)
pca.fit(train[categorical_features])
pca_train_values = pca.transform(train[categorical_features])
pca_test_values = pca.transform(test[categorical_features])

pca_train_values = np.transpose(pca_train_values, (1, 0))
pca_test_values = np.transpose(pca_test_values, (1, 0))

for e, (pca_train, pca_test) in enumerate(zip(pca_train_values, pca_test_values)):
    train[f'pca_feature_{e}'] = pca_train
    test[f'pca_feature_{e}'] = pca_test

del df
gc.collect()
# Out:
# 7

# %%
train.head()
# Out:
#            card_id  feature_1  feature_2  feature_3 first_active_month  \
# 0  C_ID_92a2005557          5          2          1         2017-06-01
# 1  C_ID_3d0044924f          4          1          0         2017-01-01
# 2  C_ID_d639edf6cd          2          2          0         2016-08-01
# 3  C_ID_186d6a6901          4          3          0         2017-09-01
# 4  C_ID_cdbd2c0db2          1          3          0         2017-11-01
#
#    outliers    target  target_raw  elapsed_time  feature_1_outliers_mean  \
# 0       0.0 -0.820283    0.566331         334.0                 0.013145
# 1       0.0  0.392913    1.313042         485.0                 0.010712
# 2       0.0  0.688056    1.611111         638.0                 0.010610
# 3       0.0  0.142495    1.103813         242.0                 0.010712
# 4       0.0 -0.159749    0.895181         181.0                 0.008058
#
#    feature_1_outliers_sum  feature_2_outliers_mean  feature_2_outliers_sum  \
# 0                   534.0                 0.008752                   655.0
# 1                   213.0                 0.011385                  1016.0
# 2                   592.0                 0.008752                   655.0
# 3                   213.0                 0.014166                   536.0
# 4                    97.0                 0.014166                   536.0
#
#    feature_3_outliers_mean  feature_3_outliers_sum  \
# 0                 0.011428                  1305.0
# 1                 0.010283                   902.0
# 2                 0.010283                   902.0
# 3                 0.010283                   902.0
# 4                 0.010283                   902.0
#
#    sum_purchase_amount_new_13  sum_purchase_amount_new_12  \
# 0                         NaN                         NaN
# 1                         NaN                     5511.95
# 2                      206.42                      253.81
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#    sum_purchase_amount_new_11  sum_purchase_amount_new_10  \
# 0                         NaN                         NaN
# 1                     2633.93                     2729.94
# 2                      116.22                      273.73
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#    sum_purchase_amount_new_9  sum_purchase_amount_new_8  \
# 0                        NaN                     112.75
# 1                    2050.80                    1429.77
# 2                     158.74                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
#
#    sum_purchase_amount_new_7  sum_purchase_amount_new_6  \
# 0                    2510.00                    1252.17
# 1                    1897.70                    3300.85
# 2                      66.38                      71.34
# 3                        NaN                        NaN
# 4                        NaN                        NaN
#
#    sum_purchase_amount_new_5  sum_purchase_amount_new_4  \
# 0                    1432.91                    1344.69
# 1                    1674.26                    5669.88
# 2                      29.86                     263.86
# 3                     243.72                    1254.03
# 4                        NaN                        NaN
#
#    sum_purchase_amount_new_3  sum_purchase_amount_new_2_x  \
# 0                    1444.36                      8178.19
# 1                    2137.24                       901.55
# 2                        NaN                        26.02
# 3                    2228.44                       362.29
# 4                    3866.92                      2161.79
#
#    sum_purchase_amount_new_1_x  sum_purchase_amount_new_0  \
# 0                      1425.84                    1084.08
# 1                      2256.74                    2019.18
# 2                       439.60                      56.98
# 3                       453.84                     795.27
# 4                      3656.80                   24022.30
#
#    count_merchant_id_13  count_merchant_id_12  count_merchant_id_11  \
# 0                   NaN                   NaN                   NaN
# 1                   NaN                  21.0                  22.0
# 2                   6.0                   6.0                   5.0
# 3                   NaN                   NaN                   NaN
# 4                   NaN                   NaN                   NaN
#
#    count_merchant_id_10  count_merchant_id_9  count_merchant_id_8  \
# 0                   NaN                  NaN                  3.0
# 1                  13.0                 18.0                 15.0
# 2                   7.0                  4.0                  NaN
# 3                   NaN                  NaN                  NaN
# 4                   NaN                  NaN                  NaN
#
#    count_merchant_id_7  count_merchant_id_6  count_merchant_id_5  \
# 0                 49.0                 44.0                 20.0
# 1                 34.0                 49.0                 14.0
# 2                  2.0                  2.0                  1.0
# 3                  NaN                  NaN                 11.0
# 4                  NaN                  NaN                  NaN
#
#    count_merchant_id_4  count_merchant_id_3  count_merchant_id_2_x  \
# 0                 22.0                 21.0                   57.0
# 1                 24.0                 26.0                   16.0
# 2                  6.0                  NaN                    1.0
# 3                 31.0                  7.0                    6.0
# 4                  NaN                 21.0                   31.0
#
#    count_merchant_id_1_x  count_merchant_id_0  hist_authorized_flag_sum  \
# 0                   21.0                 23.0                       247
# 1                   47.0                 51.0                       339
# 2                    2.0                  1.0                        41
# 3                    6.0                 16.0                        77
# 4                   46.0                 35.0                       128
#
#    hist_authorized_flag_mean  hist_purchase_amount_new_sum  \
# 0                   0.950000                      18784.99
# 1                   0.968571                      34213.79
# 2                   0.953488                       1962.96
# 3                   1.000000                       5337.59
# 4                   0.962406                      33707.81
#
#    hist_purchase_date_max  hist_purchase_date_min  hist_year_nunique  \
# 0            1.519551e+09            1.498573e+09                  2
# 1            1.517438e+09            1.483720e+09                  2
# 2            1.519759e+09            1.484123e+09                  2
# 3            1.519818e+09            1.506443e+09                  2
# 4            1.519850e+09            1.510445e+09                  2
#
#    hist_month_nunique  hist_month_mean  hist_weekofyear_nunique  \
# 0                   9         8.057692                       35
# 1                  12         6.220000                       50
# 2                  10         4.558140                       22
# 3                   6         7.740260                       20
# 4                   4         5.406015                       17
#
#    hist_weekofyear_mean  hist_day_nunique  hist_day_mean  hist_weekend_sum  \
# 0             33.073077                31      15.511538                90
# 1             25.220000                31      16.665714               132
# 2             18.372093                19      19.325581                11
# 3             32.012987                25      16.870130                11
# 4             21.781955                30      16.097744                42
#
#    hist_weekend_mean  hist_hour_nunique  hist_hour_mean  hist_category_1_sum  \
# 0           0.346154                 23       13.315385                    0
# 1           0.377143                 24       14.717143                   31
# 2           0.255814                 14       17.906977                    0
# 3           0.142857                 16       14.441558                   12
# 4           0.315789                 22       13.045113                   15
#
#    hist_category_1_mean  hist_category_2_sum  hist_category_2_mean  \
# 0              0.000000                  272              1.046154
# 1              0.088571                  319              0.911429
# 2              0.000000                  199              4.627907
# 3              0.155844                  224              2.909091
# 4              0.112782                  443              3.330827
#
#    hist_category_3_sum  hist_category_3_mean  hist_city_id_nunique  \
# 0                  776              2.984615                     7
# 1                  624              1.782857                     9
# 2                  129              3.000000                     5
# 3                  143              1.857143                     7
# 4                  259              1.947368                     6
#
#    hist_merchant_category_id_nunique  hist_merchant_id_nunique  \
# 0                                 41                        95
# 1                                 57                       142
# 2                                  8                        13
# 3                                 25                        50
# 4                                 26                        67
#
#    hist_state_id_nunique  hist_subsector_id_nunique  hist_city_minus_one_sum  \
# 0                      3                         21                        0
# 1                      3                         24                       31
# 2                      2                          7                        0
# 3                      5                         13                       12
# 4                      6                         17                       15
#
#    hist_city_minus_one_mean  hist_merchant_category_minus_one_sum  \
# 0                  0.000000                                     0
# 1                  0.088571                                     0
# 2                  0.000000                                     0
# 3                  0.155844                                     0
# 4                  0.112782                                     0
#
#    hist_merchant_category_minus_one_mean  hist_subsector_minus_one_sum  \
# 0                                    0.0                             0
# 1                                    0.0                             0
# 2                                    0.0                             0
# 3                                    0.0                             0
# 4                                    0.0                             0
#
#    hist_subsector_minus_one_mean  hist_installments_999_sum  \
# 0                            0.0                          0
# 1                            0.0                          0
# 2                            0.0                          0
# 3                            0.0                          0
# 4                            0.0                          0
#
#    hist_installments_999_mean  hist_month_lag_max  hist_month_lag_min  \
# 0                         0.0                   0                  -8
# 1                         0.0                   0                 -12
# 2                         0.0                   0                 -13
# 3                         0.0                   0                  -5
# 4                         0.0                   0                  -3
#
#    hist_month_lag_sum  hist_month_lag_mean  hist_month_lag_std  \
# 0               -1017            -3.911538            2.397687
# 1               -1761            -5.031429            3.804934
# 2                -370            -8.604651            3.842987
# 3                -218            -2.831169            1.802065
# 4                -171            -1.285714            1.026700
#
#    Y_hist_purchase_amount_new_sum  Y_hist_purchase_date_max  \
# 0                        18027.61              1.519551e+09
# 1                        29493.40              1.517438e+09
# 2                         1859.91              1.519759e+09
# 3                         5337.59              1.519818e+09
# 4                        17677.91              1.519850e+09
#
#    Y_hist_purchase_date_min  Y_hist_city_id_nunique  \
# 0              1.498573e+09                       7
# 1              1.483720e+09                       9
# 2              1.484123e+09                       5
# 3              1.506443e+09                       7
# 4              1.510445e+09                       6
#
#    Y_hist_merchant_category_id_nunique  Y_hist_merchant_id_nunique  \
# 0                                   41                          94
# 1                                   57                         141
# 2                                    8                          13
# 3                                   25                          50
# 4                                   26                          66
#
#    Y_hist_state_id_nunique  Y_hist_subsector_id_nunique  \
# 0                        3                           21
# 1                        3                           24
# 2                        2                            7
# 3                        5                           13
# 4                        6                           17
#
#    N_hist_purchase_amount_new_sum  N_hist_purchase_date_max  \
# 0                          757.38              1.514385e+09
# 1                         4720.39              1.514467e+09
# 2                          103.05              1.492801e+09
# 3                             NaN             -9.223372e+09
# 4                        16029.90              1.519759e+09
#
#    N_hist_purchase_date_min  N_hist_city_id_nunique  \
# 0              1.500131e+09                     2.0
# 1              1.488576e+09                     2.0
# 2              1.487878e+09                     1.0
# 3             -9.223372e+09                     NaN
# 4              1.516485e+09                     2.0
#
#    N_hist_merchant_category_id_nunique  N_hist_merchant_id_nunique  \
# 0                                 10.0                        13.0
# 1                                  9.0                         9.0
# 2                                  1.0                         1.0
# 3                                  NaN                         NaN
# 4                                  2.0                         2.0
#
#    N_hist_state_id_nunique  N_hist_subsector_id_nunique  \
# 0                      1.0                          7.0
# 1                      2.0                          9.0
# 2                      1.0                          1.0
# 3                      NaN                          NaN
# 4                      2.0                          2.0
#
#    sum_purchase_amount_new_1_y  sum_purchase_amount_new_2_y  \
# 0                      1512.57                      1105.92
# 1                        23.99                        59.67
# 2                          NaN                        31.00
# 3                       140.88                       241.10
# 4                      1560.33                      3073.11
#
#    count_merchant_id_1_y  count_merchant_id_2_y  new_purchase_amount_new_sum  \
# 0                   12.0                   11.0                      2618.49
# 1                    3.0                    3.0                        83.66
# 2                    NaN                    1.0                        31.00
# 3                    2.0                    5.0                       381.98
# 4                   16.0                   20.0                      4633.44
#
#    new_purchase_date_max  new_purchase_date_min  new_year_nunique  \
# 0           1.525001e+09           1.520259e+09               1.0
# 1           1.522393e+09           1.517505e+09               1.0
# 2           1.524937e+09           1.524937e+09               1.0
# 3           1.524049e+09           1.520424e+09               1.0
# 4           1.524941e+09           1.519992e+09               1.0
#
#    new_month_nunique  new_month_mean  new_weekofyear_nunique  \
# 0                2.0        3.478261                     7.0
# 1                2.0        2.500000                     4.0
# 2                1.0        4.000000                     1.0
# 3                2.0        3.714286                     5.0
# 4                2.0        3.555556                     8.0
#
#    new_weekofyear_mean  new_day_nunique  new_day_mean  new_weekend_sum  \
# 0            13.304348             17.0     16.434783              6.0
# 1             9.000000              4.0     13.500000              0.0
# 2            17.000000              1.0     28.000000              1.0
# 3            13.857143              7.0     13.142857              3.0
# 4            13.361111             22.0     14.583333             12.0
#
#    new_weekend_mean  new_hour_nunique  new_hour_mean  new_category_1_sum  \
# 0          0.260870               8.0      12.869565                 0.0
# 1          0.000000               5.0      11.166667                 0.0
# 2          1.000000               1.0      17.000000                 0.0
# 3          0.428571               5.0      13.000000                 1.0
# 4          0.333333              14.0      14.722222                 2.0
#
#    new_category_1_mean  new_category_2_sum  new_category_2_mean  \
# 0             0.000000                23.0             1.000000
# 1             0.000000                 6.0             1.000000
# 2             0.000000                 5.0             5.000000
# 3             0.142857                24.0             3.428571
# 4             0.055556               123.0             3.416667
#
#    new_category_3_sum  new_category_3_mean  new_city_id_nunique  \
# 0                69.0             3.000000                  3.0
# 1                12.0             2.000000                  1.0
# 2                 3.0             3.000000                  1.0
# 3                12.0             1.714286                  2.0
# 4                69.0             1.916667                  5.0
#
#    new_merchant_category_id_nunique  new_merchant_id_nunique  \
# 0                              14.0                     23.0
# 1                               5.0                      6.0
# 2                               1.0                      1.0
# 3                               6.0                      7.0
# 4                              17.0                     36.0
#
#    new_state_id_nunique  new_subsector_id_nunique  new_installments_999_sum  \
# 0                   1.0                      10.0                       0.0
# 1                   1.0                       4.0                       0.0
# 2                   1.0                       1.0                       0.0
# 3                   2.0                       5.0                       0.0
# 4                   5.0                      10.0                       0.0
#
#    new_installments_999_mean  new_month_lag_max  new_month_lag_min  \
# 0                        0.0                2.0                1.0
# 1                        0.0                2.0                1.0
# 2                        0.0                2.0                2.0
# 3                        0.0                2.0                1.0
# 4                        0.0                2.0                1.0
#
#    new_month_lag_sum  new_month_lag_mean  new_month_lag_std  hist_first_buy  \
# 0               34.0            1.478261           0.510754            26.0
# 1                9.0            1.500000           0.547723             5.0
# 2                2.0            2.000000                NaN           163.0
# 3               12.0            1.714286           0.487950            25.0
# 4               56.0            1.555556           0.503953            11.0
#
#    hist_last_buy  new_first_buy  new_last_buy  nans  pca_feature_0
# 0          269.0          277.0         332.0    10      -1.901802
# 1          395.0          396.0         453.0     2      -0.796380
# 2          575.0          635.0         635.0     7       1.235037
# 3          180.0          187.0         229.0    22      -0.572408
# 4          119.0          121.0         178.0    20       2.306738

# %%
test.head()
# Out:
#            card_id  feature_1  feature_2  feature_3 first_active_month  \
# 0  C_ID_0ab67a22ab          3          3          1         2017-04-01
# 1  C_ID_130fd0cbdd          2          3          0         2017-01-01
# 2  C_ID_b709037bc5          5          1          1         2017-08-01
# 3  C_ID_d27d835a9f          2          1          0         2017-12-01
# 4  C_ID_2b5e3df5c2          5          1          1         2015-12-01
#
#    outliers  target  target_raw  elapsed_time  feature_1_outliers_mean  \
# 0       NaN     NaN         NaN         395.0                 0.010479
# 1       NaN     NaN         NaN         485.0                 0.010610
# 2       NaN     NaN         NaN         273.0                 0.013145
# 3       NaN     NaN         NaN         151.0                 0.010610
# 4       NaN     NaN         NaN         882.0                 0.013145
#
#    feature_1_outliers_sum  feature_2_outliers_mean  feature_2_outliers_sum  \
# 0                   771.0                 0.014166                   536.0
# 1                   592.0                 0.014166                   536.0
# 2                   534.0                 0.011385                  1016.0
# 3                   592.0                 0.011385                  1016.0
# 4                   534.0                 0.011385                  1016.0
#
#    feature_3_outliers_mean  feature_3_outliers_sum  \
# 0                 0.011428                  1305.0
# 1                 0.010283                   902.0
# 2                 0.011428                  1305.0
# 3                 0.010283                   902.0
# 4                 0.011428                  1305.0
#
#    sum_purchase_amount_new_13  sum_purchase_amount_new_12  \
# 0                         NaN                         NaN
# 1                      741.77                      712.48
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                     8429.39                     2105.43
#
#    sum_purchase_amount_new_11  sum_purchase_amount_new_10  \
# 0                         NaN                         NaN
# 1                     1285.97                     2266.72
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                     1165.33                     2098.60
#
#    sum_purchase_amount_new_9  sum_purchase_amount_new_8  \
# 0                        NaN                     930.85
# 1                     916.86                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                    1371.89                     483.00
#
#    sum_purchase_amount_new_7  sum_purchase_amount_new_6  \
# 0                      214.0                    2178.46
# 1                        NaN                        NaN
# 2                        NaN                     149.76
# 3                        NaN                        NaN
# 4                     1240.9                    4271.54
#
#    sum_purchase_amount_new_5  sum_purchase_amount_new_4  \
# 0                      51.66                    1172.31
# 1                        NaN                        NaN
# 2                        NaN                     349.50
# 3                        NaN                        NaN
# 4                   11560.78                   10502.19
#
#    sum_purchase_amount_new_3  sum_purchase_amount_new_2_x  \
# 0                     338.92                        709.7
# 1                        NaN                          NaN
# 2                    1089.67                       1529.5
# 3                        NaN                       2569.1
# 4                    6300.00                      16011.5
#
#    sum_purchase_amount_new_1_x  sum_purchase_amount_new_0  \
# 0                       329.88                     766.39
# 1                          NaN                     147.00
# 2                      3678.00                    2679.25
# 3                       652.43                     590.99
# 4                       537.80                    5328.27
#
#    count_merchant_id_13  count_merchant_id_12  count_merchant_id_11  \
# 0                   NaN                   NaN                   NaN
# 1                  11.0                  11.0                  14.0
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4                   9.0                   2.0                  18.0
#
#    count_merchant_id_10  count_merchant_id_9  count_merchant_id_8  \
# 0                   NaN                  NaN                  4.0
# 1                  23.0                 17.0                  NaN
# 2                   NaN                  NaN                  NaN
# 3                   NaN                  NaN                  NaN
# 4                   8.0                  8.0                  2.0
#
#    count_merchant_id_7  count_merchant_id_6  count_merchant_id_5  \
# 0                  6.0                 11.0                  2.0
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  1.0                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  8.0                  5.0                  7.0
#
#    count_merchant_id_4  count_merchant_id_3  count_merchant_id_2_x  \
# 0                 11.0                  9.0                   11.0
# 1                  NaN                  NaN                    NaN
# 2                  1.0                  3.0                    3.0
# 3                  NaN                  NaN                   15.0
# 4                 10.0                  1.0                    5.0
#
#    count_merchant_id_1_x  count_merchant_id_0  hist_authorized_flag_sum  \
# 0                    4.0                 10.0                        44
# 1                    NaN                  2.0                        77
# 2                    2.0                  3.0                         9
# 3                    2.0                  9.0                        26
# 4                    4.0                 23.0                        87
#
#    hist_authorized_flag_mean  hist_purchase_amount_new_sum  \
# 0                   0.647059                       6692.17
# 1                   0.987179                       6070.80
# 2                   0.692308                       9475.68
# 3                   1.000000                       3812.52
# 4                   0.790909                      71406.62
#
#    hist_purchase_date_max  hist_purchase_date_min  hist_year_nunique  \
# 0            1.514510e+09            1.491330e+09                  1
# 1            1.518989e+09            1.484321e+09                  2
# 2            1.517598e+09            1.503673e+09                  2
# 3            1.519127e+09            1.512392e+09                  2
# 4            1.519728e+09            1.483444e+09                  2
#
#    hist_month_nunique  hist_month_mean  hist_weekofyear_nunique  \
# 0                   9         8.367647                       24
# 1                   5         3.282051                       20
# 2                   6         7.307692                        7
# 3                   3         7.692308                        6
# 4                  12         4.827273                       34
#
#    hist_weekofyear_mean  hist_day_nunique  hist_day_mean  hist_weekend_sum  \
# 0             34.544118                24      16.352941                12
# 1             12.435897                27      16.512821                17
# 2             29.000000                 7       8.538462                 0
# 3             31.115385                11      11.423077                 7
# 4             18.836364                27      13.272727                21
#
#    hist_weekend_mean  hist_hour_nunique  hist_hour_mean  hist_category_1_sum  \
# 0           0.176471                 17       14.367647                   23
# 1           0.217949                 18       14.423077                    2
# 2           0.000000                  7       17.000000                    1
# 3           0.269231                  9       17.923077                    0
# 4           0.190909                 21       14.436364                    0
#
#    hist_category_1_mean  hist_category_2_sum  hist_category_2_mean  \
# 0              0.338235                   45              0.661765
# 1              0.025641                  303              3.884615
# 2              0.076923                   56              4.307692
# 3              0.000000                   26              1.000000
# 4              0.000000                  423              3.845455
#
#    hist_category_3_sum  hist_category_3_mean  hist_city_id_nunique  \
# 0                  114              1.676471                     7
# 1                  154              1.974359                     4
# 2                   11              0.846154                     4
# 3                   41              1.576923                     1
# 4                  214              1.945455                     5
#
#    hist_merchant_category_id_nunique  hist_merchant_id_nunique  \
# 0                                 16                        24
# 1                                 16                        27
# 2                                  8                         9
# 3                                 18                        23
# 4                                 31                        47
#
#    hist_state_id_nunique  hist_subsector_id_nunique  hist_city_minus_one_sum  \
# 0                      3                         12                       23
# 1                      3                         12                        2
# 2                      4                          6                        1
# 3                      1                         11                        0
# 4                      4                         15                        0
#
#    hist_city_minus_one_mean  hist_merchant_category_minus_one_sum  \
# 0                  0.338235                                     0
# 1                  0.025641                                     0
# 2                  0.076923                                     0
# 3                  0.000000                                     0
# 4                  0.000000                                     0
#
#    hist_merchant_category_minus_one_mean  hist_subsector_minus_one_sum  \
# 0                                    0.0                             0
# 1                                    0.0                             0
# 2                                    0.0                             0
# 3                                    0.0                             0
# 4                                    0.0                             0
#
#    hist_subsector_minus_one_mean  hist_installments_999_sum  \
# 0                            0.0                          0
# 1                            0.0                          0
# 2                            0.0                          0
# 3                            0.0                          0
# 4                            0.0                          0
#
#    hist_installments_999_mean  hist_month_lag_max  hist_month_lag_min  \
# 0                         0.0                   0                  -8
# 1                         0.0                   0                 -13
# 2                         0.0                   0                  -6
# 3                         0.0                   0                  -2
# 4                         0.0                   0                 -13
#
#    hist_month_lag_sum  hist_month_lag_mean  hist_month_lag_std  \
# 0                -247            -3.632353            2.454994
# 1                -812           -10.410256            2.164866
# 2                 -27            -2.076923            1.754116
# 3                 -32            -1.230769            0.951113
# 4                -685            -6.227273            4.530547
#
#    Y_hist_purchase_amount_new_sum  Y_hist_purchase_date_max  \
# 0                         3211.27              1.514510e+09
# 1                         6060.80              1.518989e+09
# 2                         3878.23              1.517598e+09
# 3                         3812.52              1.519127e+09
# 4                        70330.62              1.519728e+09
#
#    Y_hist_purchase_date_min  Y_hist_city_id_nunique  \
# 0              1.491330e+09                       7
# 1              1.484321e+09                       4
# 2              1.503673e+09                       4
# 3              1.512392e+09                       1
# 4              1.483554e+09                       4
#
#    Y_hist_merchant_category_id_nunique  Y_hist_merchant_id_nunique  \
# 0                                   15                          23
# 1                                   16                          27
# 2                                    6                           7
# 3                                   18                          23
# 4                                   30                          45
#
#    Y_hist_state_id_nunique  Y_hist_subsector_id_nunique  \
# 0                        3                           12
# 1                        3                           12
# 2                        4                            5
# 3                        1                           11
# 4                        3                           15
#
#    N_hist_purchase_amount_new_sum  N_hist_purchase_date_max  \
# 0                         3480.90              1.513186e+09
# 1                           10.00              1.494079e+09
# 2                         5597.45              1.517593e+09
# 3                             NaN             -9.223372e+09
# 4                         1076.00              1.514992e+09
#
#    N_hist_purchase_date_min  N_hist_city_id_nunique  \
# 0              1.493303e+09                     4.0
# 1              1.494079e+09                     1.0
# 2              1.515681e+09                     1.0
# 3             -9.223372e+09                     NaN
# 4              1.483444e+09                     3.0
#
#    N_hist_merchant_category_id_nunique  N_hist_merchant_id_nunique  \
# 0                                  7.0                         7.0
# 1                                  1.0                         1.0
# 2                                  2.0                         2.0
# 3                                  NaN                         NaN
# 4                                  4.0                         5.0
#
#    N_hist_state_id_nunique  N_hist_subsector_id_nunique  \
# 0                      2.0                          7.0
# 1                      1.0                          1.0
# 2                      1.0                          1.0
# 3                      NaN                          NaN
# 4                      3.0                          4.0
#
#    sum_purchase_amount_new_1_y  sum_purchase_amount_new_2_y  \
# 0                          NaN                        308.5
# 1                       228.50                        288.9
# 2                      1114.00                          NaN
# 3                       830.74                        317.5
# 4                     10186.50                        825.0
#
#    count_merchant_id_1_y  count_merchant_id_2_y  new_purchase_amount_new_sum  \
# 0                    NaN                    3.0                       308.50
# 1                    5.0                    4.0                       517.40
# 2                    2.0                    NaN                      1114.00
# 3                    7.0                    3.0                      1148.24
# 4                    5.0                    1.0                     11011.50
#
#    new_purchase_date_max  new_purchase_date_min  new_year_nunique  \
# 0           1.519845e+09           1.517651e+09               1.0
# 1           1.524247e+09           1.520080e+09               1.0
# 2           1.520947e+09           1.519916e+09               1.0
# 3           1.524000e+09           1.520162e+09               1.0
# 4           1.523535e+09           1.520132e+09               1.0
#
#    new_month_nunique  new_month_mean  new_weekofyear_nunique  \
# 0                1.0        2.000000                     3.0
# 1                2.0        3.444444                     6.0
# 2                1.0        3.000000                     2.0
# 3                2.0        3.300000                     7.0
# 4                2.0        3.166667                     3.0
#
#    new_weekofyear_mean  new_day_nunique  new_day_mean  new_weekend_sum  \
# 0             7.000000              3.0     15.666667              1.0
# 1            12.444444              7.0     11.333333              3.0
# 2            10.000000              2.0      7.000000              0.0
# 3            12.100000              8.0     13.600000              3.0
# 4            10.500000              5.0      7.333333              2.0
#
#    new_weekend_mean  new_hour_nunique  new_hour_mean  new_category_1_sum  \
# 0          0.333333               3.0      13.666667                 0.0
# 1          0.333333               8.0      15.222222                 2.0
# 2          0.000000               2.0      13.500000                 1.0
# 3          0.300000               7.0      18.200000                 1.0
# 4          0.333333               5.0       8.000000                 0.0
#
#    new_category_1_mean  new_category_2_sum  new_category_2_mean  \
# 0             0.000000                 3.0             1.000000
# 1             0.222222                28.0             3.111111
# 2             0.500000                 5.0             2.500000
# 3             0.100000                13.0             1.300000
# 4             0.000000                23.0             3.833333
#
#    new_category_3_sum  new_category_3_mean  new_city_id_nunique  \
# 0                 5.0             1.666667                  3.0
# 1                17.0             1.888889                  2.0
# 2                 3.0             1.500000                  2.0
# 3                15.0             1.500000                  3.0
# 4                 9.0             1.500000                  2.0
#
#    new_merchant_category_id_nunique  new_merchant_id_nunique  \
# 0                               3.0                      3.0
# 1                               8.0                      9.0
# 2                               2.0                      2.0
# 3                              10.0                     10.0
# 4                               5.0                      6.0
#
#    new_state_id_nunique  new_subsector_id_nunique  new_installments_999_sum  \
# 0                   1.0                       3.0                       0.0
# 1                   2.0                       6.0                       0.0
# 2                   2.0                       2.0                       0.0
# 3                   3.0                       8.0                       0.0
# 4                   2.0                       4.0                       0.0
#
#    new_installments_999_mean  new_month_lag_max  new_month_lag_min  \
# 0                        0.0                2.0                2.0
# 1                        0.0                2.0                1.0
# 2                        0.0                1.0                1.0
# 3                        0.0                2.0                1.0
# 4                        0.0                2.0                1.0
#
#    new_month_lag_sum  new_month_lag_mean  new_month_lag_std  hist_first_buy  \
# 0                6.0            2.000000           0.000000             3.0
# 1               13.0            1.444444           0.527046            12.0
# 2                2.0            1.000000           0.000000            24.0
# 3               13.0            1.300000           0.483046             3.0
# 4                7.0            1.166667           0.408248           399.0
#
#    hist_last_buy  new_first_buy  new_last_buy  nans  pca_feature_0
# 0          272.0          308.0         333.0    15       0.129615
# 1          413.0          426.0         474.0    19       1.347023
# 2          185.0          212.0         224.0    21      -2.013788
# 3           81.0           93.0         137.0    31       1.123051
# 4          819.0          824.0         863.0     3      -2.013788

# %%
col_not_to_use = ['first_active_month', 'card_id', 'target', 'target_raw', 'outliers']
col_to_use = [c for c in train.columns if c not in col_not_to_use]

# %%
y = train['target']
y_raw = train['target_raw']

# %%
X = train[col_to_use]
X_test = test[col_to_use]

# %%
folds = KFold(n_splits=NFOLD, shuffle=True, random_state=SEED)

prediction = np.zeros(len(X_test))
scores = []

for fold_n, (train_index, valid_index) in enumerate(folds.split(X)):
    dtrain = lgb.Dataset(X.iloc[train_index], label=y.iloc[train_index])
    dvalid = lgb.Dataset(X.iloc[valid_index], label=y.iloc[valid_index])

    params = {
        'boosting': 'gbdt',
        'objective': 'regression',
        'metric': 'rmse',
        'learning_rate': 0.01,
        'subsample': 0.9855232997390695,
        'max_depth': 7,
        'top_rate': 0.9064148448434349,
        'num_leaves': 63,
        'min_child_weight': 41.9612869171337,
        'other_rate': 0.0721768246018207,
        'reg_alpha': 9.677537745007898,
        'colsample_bytree': 0.5665320670155495,
        'min_split_gain': 9.820197773625843,
        'reg_lambda': 8.2532317400459,
        'min_data_in_leaf': 21,
        'verbose': -1,
        'seed':int(2**fold_n),
        'bagging_seed':int(2**fold_n),
        'drop_seed':int(2**fold_n)
    }

    model = lgb.train(
        params,
        dtrain,
        20000,          
        valid_sets=[dtrain, dvalid],
        verbose_eval=200,
        early_stopping_rounds=200)
    
    y_pred_valid = model.predict(X.iloc[valid_index], num_iteration=model.best_iteration)
    y_pred = model.predict(X_test, num_iteration=model.best_iteration)
    
    scores.append(np.sqrt(mean_squared_error(y.iloc[valid_index], y_pred_valid)))
    
    prediction += y_pred / folds.n_splits   

    del model

print('shape:', X.shape)
print('CV {0:} mean score: {1:.4f}, std: {2:.4f}, max: {3:.4f}, min: {4:.4f}.'.format(NFOLD, np.mean(scores), np.std(scores), np.max(scores), np.min(scores)))
# Out:
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 3.6019	valid_1's rmse: 3.62655
# [400]	training's rmse: 3.52512	valid_1's rmse: 3.60909
# [600]	training's rmse: 3.48121	valid_1's rmse: 3.60587
# [800]	training's rmse: 3.44902	valid_1's rmse: 3.60458
# [1000]	training's rmse: 3.42003	valid_1's rmse: 3.60351
# [1200]	training's rmse: 3.39315	valid_1's rmse: 3.60317
# [1400]	training's rmse: 3.36559	valid_1's rmse: 3.60333
# Early stopping, best iteration is:
# [1367]	training's rmse: 3.36995	valid_1's rmse: 3.603
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 3.60558	valid_1's rmse: 3.58704
# [400]	training's rmse: 3.52976	valid_1's rmse: 3.56793
# [600]	training's rmse: 3.48643	valid_1's rmse: 3.56325
# [800]	training's rmse: 3.45353	valid_1's rmse: 3.5617
# [1000]	training's rmse: 3.42355	valid_1's rmse: 3.56182
# [1200]	training's rmse: 3.39472	valid_1's rmse: 3.56169
# Early stopping, best iteration is:
# [1044]	training's rmse: 3.41671	valid_1's rmse: 3.56125
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 3.60216	valid_1's rmse: 3.63586
# [400]	training's rmse: 3.5277	valid_1's rmse: 3.61745
# [600]	training's rmse: 3.48321	valid_1's rmse: 3.6122
# [800]	training's rmse: 3.44897	valid_1's rmse: 3.60977
# [1000]	training's rmse: 3.41931	valid_1's rmse: 3.60872
# [1200]	training's rmse: 3.39126	valid_1's rmse: 3.60761
# [1400]	training's rmse: 3.36283	valid_1's rmse: 3.60737
# [1600]	training's rmse: 3.33663	valid_1's rmse: 3.60788
# Early stopping, best iteration is:
# [1464]	training's rmse: 3.35379	valid_1's rmse: 3.60718
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 3.58147	valid_1's rmse: 3.82334
# [400]	training's rmse: 3.50638	valid_1's rmse: 3.80814
# [600]	training's rmse: 3.46101	valid_1's rmse: 3.80469
# [800]	training's rmse: 3.42623	valid_1's rmse: 3.80358
# Early stopping, best iteration is:
# [771]	training's rmse: 3.4311	valid_1's rmse: 3.80341
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 3.61016	valid_1's rmse: 3.54679
# [400]	training's rmse: 3.53384	valid_1's rmse: 3.52424
# [600]	training's rmse: 3.48672	valid_1's rmse: 3.51781
# [800]	training's rmse: 3.45451	valid_1's rmse: 3.51668
# [1000]	training's rmse: 3.42737	valid_1's rmse: 3.51632
# [1200]	training's rmse: 3.40011	valid_1's rmse: 3.51593
# [1400]	training's rmse: 3.37355	valid_1's rmse: 3.51658
# Early stopping, best iteration is:
# [1205]	training's rmse: 3.39942	valid_1's rmse: 3.51581
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 3.59356	valid_1's rmse: 3.70242
# [400]	training's rmse: 3.51819	valid_1's rmse: 3.689
# [600]	training's rmse: 3.47161	valid_1's rmse: 3.68442
# [800]	training's rmse: 3.43878	valid_1's rmse: 3.68284
# Early stopping, best iteration is:
# [753]	training's rmse: 3.44658	valid_1's rmse: 3.68256
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 3.58646	valid_1's rmse: 3.7806
# [400]	training's rmse: 3.51246	valid_1's rmse: 3.76075
# [600]	training's rmse: 3.4675	valid_1's rmse: 3.75505
# [800]	training's rmse: 3.43553	valid_1's rmse: 3.75327
# [1000]	training's rmse: 3.40497	valid_1's rmse: 3.75379
# Early stopping, best iteration is:
# [823]	training's rmse: 3.43254	valid_1's rmse: 3.75309
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 3.60406	valid_1's rmse: 3.61187
# [400]	training's rmse: 3.52842	valid_1's rmse: 3.59092
# [600]	training's rmse: 3.48493	valid_1's rmse: 3.58605
# [800]	training's rmse: 3.45326	valid_1's rmse: 3.58299
# [1000]	training's rmse: 3.42819	valid_1's rmse: 3.58255
# [1200]	training's rmse: 3.40302	valid_1's rmse: 3.58196
# [1400]	training's rmse: 3.37698	valid_1's rmse: 3.58183
# Early stopping, best iteration is:
# [1230]	training's rmse: 3.39892	valid_1's rmse: 3.58164
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 3.59828	valid_1's rmse: 3.66133
# [400]	training's rmse: 3.5229	valid_1's rmse: 3.64691
# [600]	training's rmse: 3.4797	valid_1's rmse: 3.64303
# [800]	training's rmse: 3.44659	valid_1's rmse: 3.64177
# [1000]	training's rmse: 3.41653	valid_1's rmse: 3.64043
# [1200]	training's rmse: 3.38862	valid_1's rmse: 3.63955
# [1400]	training's rmse: 3.36018	valid_1's rmse: 3.63883
# [1600]	training's rmse: 3.33164	valid_1's rmse: 3.63823
# [1800]	training's rmse: 3.30564	valid_1's rmse: 3.63796
# [2000]	training's rmse: 3.27834	valid_1's rmse: 3.6381
# Early stopping, best iteration is:
# [1880]	training's rmse: 3.29469	valid_1's rmse: 3.63775
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 3.58847	valid_1's rmse: 3.75427
# [400]	training's rmse: 3.51313	valid_1's rmse: 3.73666
# [600]	training's rmse: 3.47007	valid_1's rmse: 3.73035
# [800]	training's rmse: 3.43722	valid_1's rmse: 3.72774
# [1000]	training's rmse: 3.40779	valid_1's rmse: 3.72679
# [1200]	training's rmse: 3.38018	valid_1's rmse: 3.72658
# [1400]	training's rmse: 3.35553	valid_1's rmse: 3.72622
# Early stopping, best iteration is:
# [1357]	training's rmse: 3.36037	valid_1's rmse: 3.72597
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 3.59322	valid_1's rmse: 3.74545
# [400]	training's rmse: 3.5176	valid_1's rmse: 3.72371
# [600]	training's rmse: 3.47305	valid_1's rmse: 3.71959
# [800]	training's rmse: 3.43667	valid_1's rmse: 3.71942
# Early stopping, best iteration is:
# [697]	training's rmse: 3.45495	valid_1's rmse: 3.71896
# shape: (201917, 136)
# CV 11 mean score: 3.6537, std: 0.0855, max: 3.8034, min: 3.5158.
# ['feature_1', 'feature_2', 'feature_3']

# %%
folds = KFold(n_splits=NFOLD, shuffle=True, random_state=SEED)

prediction = np.zeros(len(X_test))
scores = []

for fold_n, (train_index, valid_index) in enumerate(folds.split(X)):
    dtrain = lgb.Dataset(X.iloc[train_index], label=y_new.iloc[train_index])
    dvalid = lgb.Dataset(X.iloc[valid_index], label=y_new.iloc[valid_index])

    params = {
        'boosting': 'gbdt',
        'objective': 'regression',
        'metric': 'rmse',
        'learning_rate': 0.01,
        'subsample': 0.9855232997390695,
        'max_depth': 7,
        'top_rate': 0.9064148448434349,
        'num_leaves': 63,
        'min_child_weight': 41.9612869171337,
        'other_rate': 0.0721768246018207,
        'reg_alpha': 9.677537745007898,
        'colsample_bytree': 0.5665320670155495,
        'min_split_gain': 9.820197773625843,
        'reg_lambda': 8.2532317400459,
        'min_data_in_leaf': 21,
        'verbose': -1,
        'seed':int(2**fold_n),
        'bagging_seed':int(2**fold_n),
        'drop_seed':int(2**fold_n)
    }

    model = lgb.train(
        params,
        dtrain,
        20000,          
        valid_sets=[dtrain, dvalid],
        verbose_eval=200,
        early_stopping_rounds=200)
    
    y_pred = model.predict(X_test, num_iteration=model.best_iteration)
    
    scores.append(np.sqrt(mean_squared_error(y.iloc[valid_index], y_pred_valid)))
    
    prediction += y_pred / folds.n_splits   

    del model

print('shape:', X.shape)
print('CV {0:} mean score: {1:.4f}, std: {2:.4f}, max: {3:.4f}, min: {4:.4f}.'.format(NFOLD, np.mean(scores), np.std(scores), np.max(scores), np.min(scores)))
print(features)

# %%
submission = pd.read_csv(os.path.join('..', 'input', 'sample_submission.csv'))
submission['target'] = prediction
submission.to_csv(os.path.join('..', 'submission', 'lightgbm_outlier_{}.csv'.format(str(datetime.datetime.today().date()).replace('-', ''))), index=False)

# %%
for i, j in zip(X.columns, X.dtypes):
    print(i, j)
# Out:
# feature_1 int64
# feature_2 int64
# feature_3 int64
# elapsed_time float64
# feature_1_outliers_mean float64
# feature_1_outliers_sum float64
# feature_2_outliers_mean float64
# feature_2_outliers_sum float64
# feature_3_outliers_mean float64
# feature_3_outliers_sum float64
# sum_purchase_amount_new_13_x float64
# sum_purchase_amount_new_12_x float64
# sum_purchase_amount_new_11_x float64
# sum_purchase_amount_new_10_x float64
# sum_purchase_amount_new_9_x float64
# sum_purchase_amount_new_8_x float64
# sum_purchase_amount_new_7_x float64
# sum_purchase_amount_new_6_x float64
# sum_purchase_amount_new_5_x float64
# sum_purchase_amount_new_4_x float64
# sum_purchase_amount_new_3_x float64
# sum_purchase_amount_new_2_x float64
# sum_purchase_amount_new_2_x float64
# sum_purchase_amount_new_2_x float64
# sum_purchase_amount_new_1_x float64
# sum_purchase_amount_new_1_x float64
# sum_purchase_amount_new_1_x float64
# sum_purchase_amount_new_0_x float64
# count_merchant_id_13_x float64
# count_merchant_id_12_x float64
# count_merchant_id_11_x float64
# count_merchant_id_10_x float64
# count_merchant_id_9_x float64
# count_merchant_id_8_x float64
# count_merchant_id_7_x float64
# count_merchant_id_6_x float64
# count_merchant_id_5_x float64
# count_merchant_id_4_x float64
# count_merchant_id_3_x float64
# count_merchant_id_2_x float64
# count_merchant_id_2_x float64
# count_merchant_id_2_x float64
# count_merchant_id_1_x float64
# count_merchant_id_1_x float64
# count_merchant_id_1_x float64
# count_merchant_id_0_x float64
# hist_authorized_flag_sum_x int64
# hist_authorized_flag_mean_x float64
# hist_authorized_flag_std float64
# hist_authorized_flag_skew float64
# hist_purchase_amount_new_sum_x float64
# hist_purchase_amount_new_mean float64
# hist_purchase_amount_new_std float64
# hist_purchase_amount_new_skew float64
# hist_purchase_date_max_x float64
# hist_purchase_date_min_x float64
# hist_year_nunique_x int64
# hist_month_nunique_x int64
# hist_month_mean_x float64
# hist_month_std float64
# hist_weekofyear_nunique_x int64
# hist_weekofyear_mean_x float64
# hist_weekofyear_std float64
# hist_day_nunique_x int64
# hist_day_mean_x float64
# hist_day_std float64
# hist_weekend_sum_x int64
# hist_weekend_mean_x float64
# hist_weekend_std float64
# hist_hour_nunique_x int64
# hist_hour_mean_x float64
# hist_hour_std float64
# hist_category_1_sum_x int64
# hist_category_1_mean_x float64
# hist_category_1_std float64
# hist_category_2_sum_x int64
# hist_category_2_mean_x float64
# hist_category_2_std float64
# hist_category_3_sum_x int64
# hist_category_3_mean_x float64
# hist_category_3_std float64
# hist_city_id_nunique_x int64
# hist_merchant_category_id_nunique_x int64
# hist_merchant_id_nunique_x int64
# hist_state_id_nunique_x int64
# hist_subsector_id_nunique_x int64
# hist_city_minus_one_sum_x int64
# hist_city_minus_one_mean_x float64
# hist_city_minus_one_std float64
# hist_merchant_category_minus_one_sum_x int64
# hist_merchant_category_minus_one_mean_x float64
# hist_merchant_category_minus_one_std float64
# hist_subsector_minus_one_sum_x int64
# hist_subsector_minus_one_mean_x float64
# hist_subsector_minus_one_std float64
# hist_installments_999_sum_x int64
# hist_installments_999_mean_x float64
# hist_installments_999_std float64
# hist_month_lag_max_x int64
# hist_month_lag_min_x int64
# hist_month_lag_sum_x int64
# hist_month_lag_mean_x float64
# hist_month_lag_std_x float64
# Y_hist_purchase_amount_new_sum_x float64
# Y_hist_purchase_amount_new_mean float64
# Y_hist_purchase_amount_new_std float64
# Y_hist_purchase_amount_new_skew float64
# Y_hist_purchase_date_max_x float64
# Y_hist_purchase_date_min_x float64
# Y_hist_month_nunique int64
# Y_hist_weekofyear_nunique int64
# Y_hist_day_nunique int64
# Y_hist_city_id_nunique_x int64
# Y_hist_merchant_category_id_nunique_x int64
# Y_hist_merchant_id_nunique_x int64
# Y_hist_state_id_nunique_x int64
# Y_hist_subsector_id_nunique_x int64
# Y_hist_month_lag_max int64
# Y_hist_month_lag_min int64
# Y_hist_month_lag_sum int64
# Y_hist_month_lag_mean float64
# Y_hist_month_lag_std float64
# N_hist_purchase_amount_new_sum_x float64
# N_hist_purchase_amount_new_mean float64
# N_hist_purchase_amount_new_std float64
# N_hist_purchase_amount_new_skew float64
# N_hist_purchase_date_max_x float64
# N_hist_purchase_date_min_x float64
# N_hist_month_nunique float64
# N_hist_weekofyear_nunique float64
# N_hist_day_nunique float64
# N_hist_city_id_nunique_x float64
# N_hist_merchant_category_id_nunique_x float64
# N_hist_merchant_id_nunique_x float64
# N_hist_state_id_nunique_x float64
# N_hist_subsector_id_nunique_x float64
# N_hist_month_lag_max float64
# N_hist_month_lag_min float64
# N_hist_month_lag_sum float64
# N_hist_month_lag_mean float64
# N_hist_month_lag_std float64
# sum_purchase_amount_new_1_y float64
# sum_purchase_amount_new_1_y float64
# sum_purchase_amount_new_1_y float64
# sum_purchase_amount_new_2_y float64
# sum_purchase_amount_new_2_y float64
# sum_purchase_amount_new_2_y float64
# count_merchant_id_1_y float64
# count_merchant_id_1_y float64
# count_merchant_id_1_y float64
# count_merchant_id_2_y float64
# count_merchant_id_2_y float64
# count_merchant_id_2_y float64
# new_purchase_amount_new_sum_x float64
# new_purchase_amount_new_mean float64
# new_purchase_amount_new_std float64
# new_purchase_amount_new_skew float64
# new_purchase_date_max_x float64
# new_purchase_date_min_x float64
# new_year_nunique_x float64
# new_month_nunique_x float64
# new_month_mean_x float64
# new_month_std float64
# new_weekofyear_nunique_x float64
# new_weekofyear_mean_x float64
# new_weekofyear_std float64
# new_day_nunique_x float64
# new_day_mean_x float64
# new_day_std float64
# new_weekend_sum_x float64
# new_weekend_mean_x float64
# new_weekend_std float64
# new_hour_nunique_x float64
# new_hour_mean_x float64
# new_hour_std float64
# new_category_1_sum_x float64
# new_category_1_mean_x float64
# new_category_2_sum_x float64
# new_category_2_mean_x float64
# new_category_3_sum_x float64
# new_category_3_mean_x float64
# new_city_id_nunique_x float64
# new_merchant_category_id_nunique_x float64
# new_merchant_id_nunique_x float64
# new_state_id_nunique_x float64
# new_subsector_id_nunique_x float64
# new_installments_999_sum_x float64
# new_installments_999_mean_x float64
# new_installments_999_std float64
# new_month_lag_max_x float64
# new_month_lag_min_x float64
# new_month_lag_sum_x float64
# new_month_lag_mean_x float64
# new_month_lag_std_x float64
# nans int64
# pca_feature_0 float64
# hist_first_buy float64
# hist_last_buy float64
# new_first_buy float64
# new_last_buy float64
# sum_purchase_amount_new_13_y float64
# sum_purchase_amount_new_12_y float64
# sum_purchase_amount_new_11_y float64
# sum_purchase_amount_new_10_y float64
# sum_purchase_amount_new_9_y float64
# sum_purchase_amount_new_8_y float64
# sum_purchase_amount_new_7_y float64
# sum_purchase_amount_new_6_y float64
# sum_purchase_amount_new_5_y float64
# sum_purchase_amount_new_4_y float64
# sum_purchase_amount_new_3_y float64
# sum_purchase_amount_new_2_x float64
# sum_purchase_amount_new_2_x float64
# sum_purchase_amount_new_2_x float64
# sum_purchase_amount_new_1_x float64
# sum_purchase_amount_new_1_x float64
# sum_purchase_amount_new_1_x float64
# sum_purchase_amount_new_0_y float64
# count_merchant_id_13_y float64
# count_merchant_id_12_y float64
# count_merchant_id_11_y float64
# count_merchant_id_10_y float64
# count_merchant_id_9_y float64
# count_merchant_id_8_y float64
# count_merchant_id_7_y float64
# count_merchant_id_6_y float64
# count_merchant_id_5_y float64
# count_merchant_id_4_y float64
# count_merchant_id_3_y float64
# count_merchant_id_2_x float64
# count_merchant_id_2_x float64
# count_merchant_id_2_x float64
# count_merchant_id_1_x float64
# count_merchant_id_1_x float64
# count_merchant_id_1_x float64
# count_merchant_id_0_y float64
# hist_authorized_flag_sum_y int64
# hist_authorized_flag_mean_y float64
# hist_purchase_amount_new_sum_y float64
# hist_purchase_date_max_y datetime64[ns]
# hist_purchase_date_min_y datetime64[ns]
# hist_year_nunique_y int64
# hist_month_nunique_y int64
# hist_month_mean_y float64
# hist_weekofyear_nunique_y int64
# hist_weekofyear_mean_y float64
# hist_day_nunique_y int64
# hist_day_mean_y float64
# hist_weekend_sum_y int64
# hist_weekend_mean_y float64
# hist_hour_nunique_y int64
# hist_hour_mean_y float64
# hist_category_1_sum_y int64
# hist_category_1_mean_y float64
# hist_category_2_sum_y int64
# hist_category_2_mean_y float64
# hist_category_3_sum_y int64
# hist_category_3_mean_y float64
# hist_city_id_nunique_y int64
# hist_merchant_category_id_nunique_y int64
# hist_merchant_id_nunique_y int64
# hist_state_id_nunique_y int64
# hist_subsector_id_nunique_y int64
# hist_city_minus_one_sum_y int64
# hist_city_minus_one_mean_y float64
# hist_merchant_category_minus_one_sum_y int64
# hist_merchant_category_minus_one_mean_y float64
# hist_subsector_minus_one_sum_y int64
# hist_subsector_minus_one_mean_y float64
# hist_installments_999_sum_y int64
# hist_installments_999_mean_y float64
# hist_month_lag_max_y int64
# hist_month_lag_min_y int64
# hist_month_lag_sum_y int64
# hist_month_lag_mean_y float64
# hist_month_lag_std_y float64
# Y_hist_purchase_amount_new_sum_y float64
# Y_hist_purchase_date_max_y datetime64[ns]
# Y_hist_purchase_date_min_y datetime64[ns]
# Y_hist_city_id_nunique_y int64
# Y_hist_merchant_category_id_nunique_y int64
# Y_hist_merchant_id_nunique_y int64
# Y_hist_state_id_nunique_y int64
# Y_hist_subsector_id_nunique_y int64
# N_hist_purchase_amount_new_sum_y float64
# N_hist_purchase_date_max_y datetime64[ns]
# N_hist_purchase_date_min_y datetime64[ns]
# N_hist_city_id_nunique_y float64
# N_hist_merchant_category_id_nunique_y float64
# N_hist_merchant_id_nunique_y float64
# N_hist_state_id_nunique_y float64
# N_hist_subsector_id_nunique_y float64
# sum_purchase_amount_new_1_y float64
# sum_purchase_amount_new_1_y float64
# sum_purchase_amount_new_1_y float64
# sum_purchase_amount_new_2_y float64
# sum_purchase_amount_new_2_y float64
# sum_purchase_amount_new_2_y float64
# count_merchant_id_1_y float64
# count_merchant_id_1_y float64
# count_merchant_id_1_y float64
# count_merchant_id_2_y float64
# count_merchant_id_2_y float64
# count_merchant_id_2_y float64
# new_purchase_amount_new_sum_y float64
# new_purchase_date_max_y datetime64[ns]
# new_purchase_date_min_y datetime64[ns]
# new_year_nunique_y float64
# new_month_nunique_y float64
# new_month_mean_y float64
# new_weekofyear_nunique_y float64
# new_weekofyear_mean_y float64
# new_day_nunique_y float64
# new_day_mean_y float64
# new_weekend_sum_y float64
# new_weekend_mean_y float64
# new_hour_nunique_y float64
# new_hour_mean_y float64
# new_category_1_sum_y float64
# new_category_1_mean_y float64
# new_category_2_sum_y float64
# new_category_2_mean_y float64
# new_category_3_sum_y float64
# new_category_3_mean_y float64
# new_city_id_nunique_y float64
# new_merchant_category_id_nunique_y float64
# new_merchant_id_nunique_y float64
# new_state_id_nunique_y float64
# new_subsector_id_nunique_y float64
# new_installments_999_sum_y float64
# new_installments_999_mean_y float64
# new_month_lag_max_y float64
# new_month_lag_min_y float64
# new_month_lag_sum_y float64
# new_month_lag_mean_y float64
# new_month_lag_std_y float64
# sum_purchase_amount_new_13 float64
# sum_purchase_amount_new_12 float64
# sum_purchase_amount_new_11 float64
# sum_purchase_amount_new_10 float64
# sum_purchase_amount_new_9 float64
# sum_purchase_amount_new_8 float64
# sum_purchase_amount_new_7 float64
# sum_purchase_amount_new_6 float64
# sum_purchase_amount_new_5 float64
# sum_purchase_amount_new_4 float64
# sum_purchase_amount_new_3 float64
# sum_purchase_amount_new_2_x float64
# sum_purchase_amount_new_2_x float64
# sum_purchase_amount_new_2_x float64
# sum_purchase_amount_new_1_x float64
# sum_purchase_amount_new_1_x float64
# sum_purchase_amount_new_1_x float64
# sum_purchase_amount_new_0 float64
# count_merchant_id_13 float64
# count_merchant_id_12 float64
# count_merchant_id_11 float64
# count_merchant_id_10 float64
# count_merchant_id_9 float64
# count_merchant_id_8 float64
# count_merchant_id_7 float64
# count_merchant_id_6 float64
# count_merchant_id_5 float64
# count_merchant_id_4 float64
# count_merchant_id_3 float64
# count_merchant_id_2_x float64
# count_merchant_id_2_x float64
# count_merchant_id_2_x float64
# count_merchant_id_1_x float64
# count_merchant_id_1_x float64
# count_merchant_id_1_x float64
# count_merchant_id_0 float64
# hist_authorized_flag_sum int64
# hist_authorized_flag_mean float64
# hist_purchase_amount_new_sum float64
# hist_purchase_date_max float64
# hist_purchase_date_min float64
# hist_year_nunique int64
# hist_month_nunique int64
# hist_month_mean float64
# hist_weekofyear_nunique int64
# hist_weekofyear_mean float64
# hist_day_nunique int64
# hist_day_mean float64
# hist_weekend_sum int64
# hist_weekend_mean float64
# hist_hour_nunique int64
# hist_hour_mean float64
# hist_category_1_sum int64
# hist_category_1_mean float64
# hist_category_2_sum int64
# hist_category_2_mean float64
# hist_category_3_sum int64
# hist_category_3_mean float64
# hist_city_id_nunique int64
# hist_merchant_category_id_nunique int64
# hist_merchant_id_nunique int64
# hist_state_id_nunique int64
# hist_subsector_id_nunique int64
# hist_city_minus_one_sum int64
# hist_city_minus_one_mean float64
# hist_merchant_category_minus_one_sum int64
# hist_merchant_category_minus_one_mean float64
# hist_subsector_minus_one_sum int64
# hist_subsector_minus_one_mean float64
# hist_installments_999_sum int64
# hist_installments_999_mean float64
# hist_month_lag_max int64
# hist_month_lag_min int64
# hist_month_lag_sum int64
# hist_month_lag_mean float64
# hist_month_lag_std float64
# Y_hist_purchase_amount_new_sum float64
# Y_hist_purchase_date_max float64
# Y_hist_purchase_date_min float64
# Y_hist_city_id_nunique int64
# Y_hist_merchant_category_id_nunique int64
# Y_hist_merchant_id_nunique int64
# Y_hist_state_id_nunique int64
# Y_hist_subsector_id_nunique int64
# N_hist_purchase_amount_new_sum float64
# N_hist_purchase_date_max float64
# N_hist_purchase_date_min float64
# N_hist_city_id_nunique float64
# N_hist_merchant_category_id_nunique float64
# N_hist_merchant_id_nunique float64
# N_hist_state_id_nunique float64
# N_hist_subsector_id_nunique float64
# sum_purchase_amount_new_1_y float64
# sum_purchase_amount_new_1_y float64
# sum_purchase_amount_new_1_y float64
# sum_purchase_amount_new_2_y float64
# sum_purchase_amount_new_2_y float64
# sum_purchase_amount_new_2_y float64
# count_merchant_id_1_y float64
# count_merchant_id_1_y float64
# count_merchant_id_1_y float64
# count_merchant_id_2_y float64
# count_merchant_id_2_y float64
# count_merchant_id_2_y float64
# new_purchase_amount_new_sum float64
# new_purchase_date_max float64
# new_purchase_date_min float64
# new_year_nunique float64
# new_month_nunique float64
# new_month_mean float64
# new_weekofyear_nunique float64
# new_weekofyear_mean float64
# new_day_nunique float64
# new_day_mean float64
# new_weekend_sum float64
# new_weekend_mean float64
# new_hour_nunique float64
# new_hour_mean float64
# new_category_1_sum float64
# new_category_1_mean float64
# new_category_2_sum float64
# new_category_2_mean float64
# new_category_3_sum float64
# new_category_3_mean float64
# new_city_id_nunique float64
# new_merchant_category_id_nunique float64
# new_merchant_id_nunique float64
# new_state_id_nunique float64
# new_subsector_id_nunique float64
# new_installments_999_sum float64
# new_installments_999_mean float64
# new_month_lag_max float64
# new_month_lag_min float64
# new_month_lag_sum float64
# new_month_lag_mean float64
# new_month_lag_std float64

# %%
historical_transactions[['installments', 'month_lag', 'purchase_date']]
# Out:
#           installments  month_lag        purchase_date
# 0                    0         -8  2017-06-25 15:33:07
# 1                    0         -7  2017-07-15 12:10:45
# 2                    0         -6  2017-08-09 22:04:29
# 3                    0         -5  2017-09-02 10:06:26
# 4                    0        -11  2017-03-10 01:14:19
# 5                    0          0  2018-02-24 08:45:05
# 6                    0        -11  2017-03-21 00:10:51
# 7                    0         -3  2017-11-18 20:05:55
# 8                    0         -8  2017-06-01 22:02:56
# 9                    0        -11  2017-03-16 15:41:22
# 10                   0         -9  2017-05-09 12:42:07
# 11                   0          0  2018-02-08 20:05:45
# 12                   0         -8  2017-06-08 18:02:29
# 13                   0         -7  2017-07-14 12:59:38
# 14                   0         -4  2017-10-24 13:29:29
# 15                   0         -8  2017-06-14 07:40:48
# 16                   0          0  2018-02-07 12:19:33
# 17                   0         -7  2017-07-07 13:03:27
# 18                   0         -1  2018-01-08 23:54:29
# 19                   0         -6  2017-08-11 17:53:00
# 20                   0         -6  2017-08-30 12:53:57
# 21                   0         -7  2017-07-01 21:27:23
# 22                   0         -7  2017-07-14 22:06:02
# 23                   0         -9  2017-05-06 12:29:50
# 24                   0        -13  2017-01-20 09:16:43
# 25                   0          0  2018-02-26 14:54:38
# 26                   0        -10  2017-04-29 12:30:03
# 27                   0         -8  2017-06-23 21:43:17
# 28                   0        -11  2017-03-10 15:46:19
# 29                   0         -6  2017-08-05 19:10:32
# ...                ...        ...                  ...
# 29112331             1         -7  2017-07-12 18:01:13
# 29112332            10         -6  2017-08-03 15:06:50
# 29112333             8          0  2018-01-29 15:08:56
# 29112334             4         -1  2017-12-11 19:03:31
# 29112335             0         -1  2017-01-06 14:54:55
# 29112336             0          0  2017-02-07 16:02:48
# 29112337             0         -1  2017-12-05 12:38:59
# 29112338             0         -3  2017-10-07 20:00:40
# 29112339             0         -3  2017-10-02 00:35:15
# 29112340             1         -1  2018-01-01 18:33:46
# 29112341             1          0  2018-02-01 18:06:30
# 29112342             1         -2  2017-12-24 00:19:52
# 29112343             0         -3  2017-11-26 02:27:39
# 29112344             0         -2  2017-12-30 19:36:04
# 29112345             0         -5  2017-09-23 22:42:58
# 29112346             0          0  2018-02-20 14:18:46
# 29112347             0         -8  2017-06-01 16:55:08
# 29112348             0         -9  2017-05-20 16:55:17
# 29112349             2         -2  2017-09-18 20:35:39
# 29112350             2         -3  2017-08-08 14:36:26
# 29112351             2         -3  2017-08-29 11:43:46
# 29112352             3         -3  2017-08-29 11:28:25
# 29112353             1         -2  2017-12-29 14:43:53
# 29112354             1         -1  2018-01-23 01:52:28
# 29112355             1          0  2018-02-07 18:17:01
# 29112356             1         -1  2017-01-20 08:52:04
# 29112357             1          0  2017-02-20 04:40:50
# 29112358             0          0  2017-12-26 18:37:51
# 29112359             0         -1  2017-11-24 14:18:15
# 29112360             0         -2  2017-10-26 14:09:40
#
# [29112361 rows x 3 columns]
