# %%
import os
import numpy as np
import pandas as pd

# %%
PREF = 'f103'

KEY = 'card_id'

stats = ['min', 'max', 'mean', 'median', 'std', 'var', 'skew', 'count']

# %%
PATH = os.path.join('..', 'data')

historical_transactions = pd.read_csv(os.path.join(PATH, 'historical_transactions.csv'))
historical_transactions['installments'] = historical_transactions['installments'].astype(int)

# %%
num_aggregations = {
    'purchase_amount': stats,
    'installments': stats
}

# %%
grouped = historical_transactions.groupby(['card_id', 'authorized_flag'])
agg = grouped.agg(num_aggregations)
agg.columns = ['_'.join(col).strip() for col in agg.columns.values]
agg.reset_index(inplace=True)

# %%
agg.head()
# Out:
#            card_id  authorized_flag  purchase_amount_min  purchase_amount_max  \
# 0  C_ID_00007093c1                0            -0.728876             1.507069
# 1  C_ID_00007093c1                1            -0.728876             1.206539
# 2  C_ID_0001238066                0            -0.596643            -0.596643
# 3  C_ID_0001238066                1            -0.734887             0.768095
# 4  C_ID_0001506ef0                0            -0.740491            -0.708590
#
#    purchase_amount_mean  purchase_amount_median  purchase_amount_std  \
# 0             -0.411485               -0.569219             0.430059
# 1             -0.547746               -0.596643             0.237426
# 2             -0.596643               -0.596643             0.000000
# 3             -0.588811               -0.650122             0.192614
# 4             -0.726445               -0.728350             0.016203
#
#    purchase_amount_var  purchase_amount_skew  purchase_amount_count  \
# 0             0.184951              3.035875                     35
# 1             0.056371              4.183977                    114
# 2             0.000000              0.000000                      3
# 3             0.037100              4.006112                    120
# 4             0.000263              0.218985                      4
#
#    installments_min  installments_max  installments_mean  installments_median  \
# 0                 1                 3           1.285714                  1.0
# 1                 1                 6           1.289474                  1.0
# 2                 1                 1           1.000000                  1.0
# 3                -1                10           1.625000                  1.0
# 4                 0                 1           0.250000                  0.0
#
#    installments_std  installments_var  installments_skew  installments_count
# 0          0.667367          0.445378           2.120415                  35
# 1          0.795159          0.632278           3.514956                 114
# 2          0.000000          0.000000           0.000000                   3
# 3          1.501050          2.253151           2.893080                 120
# 4          0.500000          0.250000           2.000000                   4

# %%
agg_Y = agg[agg.authorized_flag == 1].add_prefix('Y_')
agg_Y = agg_Y.rename(columns={'Y_card_id': 'card_id'})
agg_N = agg[agg.authorized_flag == 0].add_prefix('N_')
agg_N = agg_N.rename(columns={'N_card_id': 'card_id'})

# %%
agg_Y.head()
# Out:
#            card_id  Y_purchase_amount_min  Y_purchase_amount_max  \
# 1  C_ID_00007093c1              -0.728876               1.206539
# 3  C_ID_0001238066              -0.734887               0.768095
# 5  C_ID_0001506ef0              -0.740491               1.493545
# 7  C_ID_0001793786              -0.737892               4.554145
# 9  C_ID_000183fdda              -0.737892               2.764788
#
#    Y_purchase_amount_mean  Y_purchase_amount_median  Y_purchase_amount_std  \
# 1               -0.547746                 -0.596643               0.237426
# 3               -0.588811                 -0.650122               0.192614
# 5               -0.511227                 -0.700220               0.484575
# 7               -0.132067                 -0.447880               0.867916
# 9               -0.495595                 -0.670693               0.523760
#
#    Y_purchase_amount_var  Y_purchase_amount_skew  Y_purchase_amount_count  \
# 1               0.056371                4.183977                      114
# 3               0.037100                4.006112                      120
# 5               0.234813                2.583079                       62
# 7               0.753279                2.909714                      189
# 9               0.274325                4.088246                      137
#
#    Y_installments_min  Y_installments_max  Y_installments_mean  \
# 1                   1                   6             1.289474
# 3                  -1                  10             1.625000
# 5                   0                   0             0.000000
# 7                   0                   0             0.000000
# 9                  -1                  10             1.788321
#
#    Y_installments_median  Y_installments_std  Y_installments_var  \
# 1                    1.0            0.795159            0.632278
# 3                    1.0            1.501050            2.253151
# 5                    0.0            0.000000            0.000000
# 7                    0.0            0.000000            0.000000
# 9                    1.0            2.108912            4.447510
#
#    Y_installments_skew  Y_installments_count
# 1             3.514956                   114
# 3             2.893080                   120
# 5             0.000000                    62
# 7             0.000000                   189
# 9             2.799102                   137

# %%
del agg_Y['Y_authorized_flag']

# %%
agg_Y = agg_Y.groupby('card_id').agg(['mean', 'std', 'var', 'skew'])
agg_Y.columns = ['hist_'+'_'.join(col).strip() for col in agg_Y.columns.values]
agg_Y = agg_Y.reset_index()
agg_Y = agg_Y.rename(columns={'hist_card_id': 'card_id'})
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-3ffc5144a693> in <module>()
# ----> 1 agg_Y = agg_Y.groupby('card_id').agg(['mean', 'std', 'var', 'skew'])
#       2 agg_Y.columns = ['hist_'+'_'.join(col).strip() for col in agg_Y.columns.values]
#       3 agg_Y = agg_Y.reset_index()
#       4 agg_Y = agg_Y.rename(columns={'hist_card_id': 'card_id'})
#
# /anaconda/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in aggregate(self, arg, *args, **kwargs)
#    4654         axis=''))
#    4655     def aggregate(self, arg, *args, **kwargs):
# -> 4656         return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#    4657
#    4658     agg = aggregate
#
# /anaconda/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in aggregate(self, arg, *args, **kwargs)
#    4085
#    4086         _level = kwargs.pop('_level', None)
# -> 4087         result, how = self._aggregate(arg, _level=_level, *args, **kwargs)
#    4088         if how is None:
#    4089             return result
#
# /anaconda/lib/python3.6/site-packages/pandas/core/base.py in _aggregate(self, arg, *args, **kwargs)
#     549             return self._aggregate_multiple_funcs(arg,
#     550                                                   _level=_level,
# --> 551                                                   _axis=_axis), None
#     552         else:
#     553             result = None
#
# /anaconda/lib/python3.6/site-packages/pandas/core/base.py in _aggregate_multiple_funcs(self, arg, _level, _axis)
#     595                     colg = self._gotitem(col, ndim=1,
#     596                                          subset=obj.iloc[:, index])
# --> 597                     results.append(colg.aggregate(arg))
#     598                     keys.append(col)
#     599                 except (TypeError, DataError):
#
# /anaconda/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in aggregate(self, func_or_funcs, *args, **kwargs)
#    3483             # but not the class list / tuple itself.
#    3484             ret = self._aggregate_multiple_funcs(func_or_funcs,
# -> 3485                                                  (_level or 0) + 1)
#    3486         else:
#    3487             cyfunc = self._is_cython_func(func_or_funcs)
#
# /anaconda/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _aggregate_multiple_funcs(self, arg, _level)
#    3556                 obj._reset_cache()
#    3557                 obj._selection = name
# -> 3558             results[name] = obj.aggregate(func)
#    3559
#    3560         if any(isinstance(x, DataFrame) for x in compat.itervalues(results)):
#
# /anaconda/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in aggregate(self, func_or_funcs, *args, **kwargs)
#    3477         _level = kwargs.pop('_level', None)
#    3478         if isinstance(func_or_funcs, compat.string_types):
# -> 3479             return getattr(self, func_or_funcs)(*args, **kwargs)
#    3480
#    3481         if isinstance(func_or_funcs, collections.Iterable):
#
# /anaconda/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in wrapper(*args, **kwargs)
#     833
#     834             try:
# --> 835                 return self.apply(curried_with_axis)
#     836             except Exception:
#     837                 try:
#
# /anaconda/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#    3467                       examples=_apply_docs['series_examples']))
#    3468     def apply(self, func, *args, **kwargs):
# -> 3469         return super(SeriesGroupBy, self).apply(func, *args, **kwargs)
#    3470
#    3471     @Appender(_agg_doc)
#
# /anaconda/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     916         with option_context('mode.chained_assignment', None):
#     917             try:
# --> 918                 result = self._python_apply_general(f)
#     919             except Exception:
#     920
#
# /anaconda/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f)
#     934     def _python_apply_general(self, f):
#     935         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 936                                                    self.axis)
#     937
#     938         return self._wrap_applied_output(
#
# /anaconda/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in apply(self, f, data, axis)
#    2266
#    2267         result_values = []
# -> 2268         for key, (i, group) in zip(group_keys, splitter):
#    2269             object.__setattr__(group, 'name', key)
#    2270
#
# /anaconda/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in __iter__(self)
#    5053             #     raise AssertionError('Start %s must be less than end %s'
#    5054             #                          % (str(start), str(end)))
# -> 5055             yield i, self._chop(sdata, slice(start, end))
#    5056
#    5057     def _get_sorted_data(self):
#
# /anaconda/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _chop(self, sdata, slice_obj)
#    5068
#    5069     def _chop(self, sdata, slice_obj):
# -> 5070         return sdata._get_values(slice_obj).to_dense()
#    5071
#    5072
#
# /anaconda/lib/python3.6/site-packages/pandas/core/series.py in _get_values(self, indexer)
#     876         try:
#     877             return self._constructor(self._data.get_slice(indexer),
# --> 878                                      fastpath=True).__finalize__(self)
#     879         except Exception:
#     880             return self._values[indexer]
#
# /anaconda/lib/python3.6/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     171
#     172             # data is an ndarray, index is defined
# --> 173             if not isinstance(data, SingleBlockManager):
#     174                 data = SingleBlockManager(data, index, fastpath=True)
#     175             if copy:
#
# KeyboardInterrupt:

# %%
agg_N = agg_N.groupby('card_id').agg(['mean', 'std', 'var', 'skew'])
agg_N.columns = ['hist_'+'_'.join(col).strip() for col in agg_N.columns.values]
agg_N = agg_N.reset_index()
agg_N = agg_N.rename(columns={'hist_card_id': 'card_id'})
