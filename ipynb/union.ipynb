# %%
import os
import sys
import gc

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
PATH = os.path.join('..', 'input')

# %%
train = pd.read_csv(os.path.join(PATH, 'train.csv'))

# %%
test = pd.read_csv(os.path.join(PATH, 'test.csv'))

# %%
train = train.sort_values(by='first_active_month')

# %%
train.tail()
# Out:
#        first_active_month          card_id  feature_1  feature_2  feature_3  \
# 184179            2018-01  C_ID_23387671fa          2          1          0
# 13811             2018-01  C_ID_717c6f2883          4          2          0
# 93825             2018-01  C_ID_7efaf68a69          1          1          0
# 64329             2018-01  C_ID_74204306cd          4          1          0
# 43740             2018-02  C_ID_668b351e9f          1          2          0
#
#           target
# 184179  2.064175
# 13811   0.000000
# 93825   1.400116
# 64329  -0.300675
# 43740   0.155150

# %%
test = test.sort_values(by='first_active_month')

# %%
historical_transactions = pd.read_csv(os.path.join(PATH, 'historical_transactions.csv'))

# %%
new_merchant_transactions = pd.read_csv(os.path.join(PATH, 'new_merchant_transactions.csv'))

# %%
historical_transactions = historical_transactions.sort_values(by='purchase_date')

# %%
historical_transactions.head()
# Out:
#          authorized_flag          card_id  city_id category_1  installments  \
# 7289521                Y  C_ID_da2090f28e       69          N             0
# 18512762               Y  C_ID_efced389a0       76          N             1
# 14942234               Y  C_ID_83561fe74a      233          N             1
# 28659693               Y  C_ID_479fd6392a       -1          Y             1
# 20004812               Y  C_ID_1cf6056088       69          N             0
#
#          category_3  merchant_category_id      merchant_id  month_lag  \
# 7289521           A                   623  M_ID_f001319a61        -11
# 18512762          B                   842  M_ID_18038b5ae7        -12
# 14942234          B                   661  M_ID_52d3026407        -13
# 28659693          B                   839  M_ID_e5374dabc0         -1
# 20004812          A                   278  M_ID_2cf6dc1f6f         -4
#
#           purchase_amount        purchase_date  category_2  state_id  \
# ...

# %%
new_merchant_transactions = new_merchant_transactions.sort_values(by='purchase_date')

# %%
new_merchant_transactions.head()
# Out:
#         authorized_flag          card_id  city_id category_1  installments  \
# 355331                Y  C_ID_7c628841cb       69          N             1
# 1371578               Y  C_ID_25d399500c       19          N             1
# 1578963               Y  C_ID_e3542c52f1      199          N             0
# 1073844               Y  C_ID_fabd47ca44       69          N             0
# 530878                Y  C_ID_6f9a771d17       96          N             1
#
#         category_3  merchant_category_id      merchant_id  month_lag  \
# 355331           B                    80  M_ID_c03b62d83d          1
# 1371578          B                   307  M_ID_2445d76702          1
# 1578963          A                   307  M_ID_b16ae63c45          1
# 1073844          A                    80  M_ID_b35d0757d1          1
# 530878           B                   178  M_ID_b6b9b8ed67          1
#
#          purchase_amount        purchase_date  category_2  state_id  \
# ...

# %%
new_merchant_transactions.tail()
# Out:
#         authorized_flag          card_id  city_id category_1  installments  \
# 802701                Y  C_ID_251e1fe58f       57          N             0
# 1717490               Y  C_ID_246d26c2bd       69          N             1
# 522042                Y  C_ID_0d0b14e74d        8          N             0
# 1644276               Y  C_ID_5a05b5e813       19          N             1
# 245775                Y  C_ID_77fd0634b1      136          N             0
#
#         category_3  merchant_category_id      merchant_id  month_lag  \
# 802701           A                   307  M_ID_a0eef20623          2
# 1717490          B                   818  M_ID_5bf40b6a6f          2
# 522042           A                   842  M_ID_08b7605111          2
# 1644276          B                    80  M_ID_2bc04b5299          2
# 245775           A                   842  M_ID_066936e35c          2
#
#          purchase_amount        purchase_date  category_2  state_id  \
# ...

# %%
new_merchant_transactions['purchase_date'] = pd.to_datetime(new_merchant_transactions['purchase_date'])

# %%
new_merchant_transactions.head()
# Out:
#         authorized_flag          card_id  city_id category_1  installments  \
# 355331                Y  C_ID_7c628841cb       69          N             1
# 1371578               Y  C_ID_25d399500c       19          N             1
# 1578963               Y  C_ID_e3542c52f1      199          N             0
# 1073844               Y  C_ID_fabd47ca44       69          N             0
# 530878                Y  C_ID_6f9a771d17       96          N             1
#
#         category_3  merchant_category_id      merchant_id  month_lag  \
# 355331           B                    80  M_ID_c03b62d83d          1
# 1371578          B                   307  M_ID_2445d76702          1
# 1578963          A                   307  M_ID_b16ae63c45          1
# 1073844          A                    80  M_ID_b35d0757d1          1
# 530878           B                   178  M_ID_b6b9b8ed67          1
#
#          purchase_amount       purchase_date  category_2  state_id  \
# ...

# %%
new_merchant_transactions['year'] = new_merchant_transactions['purchase_date'].dt.year
new_merchant_transactions['month'] = new_merchant_transactions['purchase_date'].dt.month

# %%
new_merchant_transactions = new_merchant_transactions.sort_values(by='purchase_date').reset_index(drop=True)

# %%
new_merchant_transactions.head()
# Out:
#      index authorized_flag          card_id  city_id category_1  installments  \
# 0   355331               Y  C_ID_7c628841cb       69          N             1
# 1  1371578               Y  C_ID_25d399500c       19          N             1
# 2  1578963               Y  C_ID_e3542c52f1      199          N             0
# 3  1073844               Y  C_ID_fabd47ca44       69          N             0
# 4   530878               Y  C_ID_6f9a771d17       96          N             1
#
#   category_3  merchant_category_id      merchant_id  month_lag  \
# 0          B                    80  M_ID_c03b62d83d          1
# 1          B                   307  M_ID_2445d76702          1
# 2          A                   307  M_ID_b16ae63c45          1
# 3          A                    80  M_ID_b35d0757d1          1
# 4          B                   178  M_ID_b6b9b8ed67          1
#
#    purchase_amount       purchase_date  category_2  state_id  subsector_id  \
# ...

# %%
new_merchant_transactions.tail()
# Out:
#            index authorized_flag          card_id  city_id category_1  \
# 1963026   802701               Y  C_ID_251e1fe58f       57          N
# 1963027  1717490               Y  C_ID_246d26c2bd       69          N
# 1963028   522042               Y  C_ID_0d0b14e74d        8          N
# 1963029  1644276               Y  C_ID_5a05b5e813       19          N
# 1963030   245775               Y  C_ID_77fd0634b1      136          N
#
#          installments category_3  merchant_category_id      merchant_id  \
# 1963026             0          A                   307  M_ID_a0eef20623
# 1963027             1          B                   818  M_ID_5bf40b6a6f
# 1963028             0          A                   842  M_ID_08b7605111
# 1963029             1          B                    80  M_ID_2bc04b5299
# 1963030             0          A                   842  M_ID_066936e35c
#
#          month_lag  purchase_amount       purchase_date  category_2  state_id  \
# ...
